# %%
# %load_ext dotenv
# %dotenv

# %% [markdown]
# # What are we doing?
#
# ## Objectives
#
#
# * Build a data pipeline that downloads price data from the internet, stores it locally, transforms it into return data, and stores the feature set.
#     - Getting the data.
#     - Schemas and index in Dask.
#
# * Explore the parquet format.
#     - Reading and writing parquet files.
#     - Read datasets that are stored in distributed files.
#     - Discuss Dask vs. Pandas as a small example of big vs small data.
#
# * Discuss the use of environment variables for settings.
# * Discuss how to use Jupyter notebooks and source code concurrently.
# * Logging and using a standard logger.
#
# ## About the Data
#
# + We will download the prices for a list of stocks.
# + The source is Yahoo Finance, and the data, along with its description, is available via [Kaggle](https://www.kaggle.com/datasets/jacksoncrow/stock-market-dataset).
#
#
# ## Medallion Architecture
#
# + The architecture that we are thinking about is called Medallion by [DataBricks](https://www.databricks.com/glossary/medallion-architecture). It is an ELT type of thinking, although our data is well-structured.
#
# <div>
# <img src="./images/02_medallion_architecture.png" height=300>
# </div>
#
# + In our case, we would like to optimize the number of times that we download data from the internet.
# + Ultimately, we will build a pipeline manager class to control the process of obtaining and transforming our data.
#
# <div>
# <img src="./images/02_target_pipeline_manager.png" height=250>
# </div>

# %% [markdown]
# # Download Data
#
# Download the [Stock Market Dataset from Kaggle](https://www.kaggle.com/datasets/jacksoncrow/stock-market-dataset). Note that you may be required to register for a free account. Alternatively, download the file from [this location](https://drive.google.com/drive/folders/1AA4gapDLpI194TGce1bY25sd91Km-tU3?usp=drive_link).
#
# + Extract stock prices (not ETFs) into the directory: `./05_src/data/prices_csv/`.
# + To be clear, your folder structure should include the path `05_src/data/prices_csv/stocks`.

# %% [markdown]
# The command `%run update_path.py` runs a local script that adds the repository's `../../05_src/` directory to the notebook's kernel path. This way, we can use our modules within the notebook.

# %%
# %run update_path.py

# %% [markdown]
# To load the historical price data for stocks and ETFs, use the code below. Notice the following:
#
# + Libraries are ordered from high-level to low-level libraries from the package manager. Local modules are imported at the end.
# + The function `get_logger()` is called with `__name__` as recommended by [Python's documentation](https://docs.python.org/3/howto/logging.html#logging-advanced-tutorial).

# %%
from glob import glob
import os
import pandas as pd
import random

from utils.logger import get_logger
_logs = get_logger(__name__)

# %% [markdown]
# + The [`glob` module](https://docs.python.org/3/library/glob.html) is used for finding path names that match specified patterns using Unix shell-style rules.
#
# + Notice that the module `glob` contains a function called `glob`; therefore, we used `from glob import glob` above.
#
# + The path in which we are searching for our csv files is produced by joining two strings:
#
#
#
#     - The value of the environment variable 'SRC_DIR' that we obtain with `os.getenv('SRC_DIR')` (this variable points to ./05_src).
#
#     - Another string given by "data/prices_csv/stocks/*.csv".
#
#     - Both strings are combined into an OS-consistent path using `os.path.join(...)`.
#
# + After we know the location of all our files, we sample a subset of them.

# %%
stock_files = glob(os.path.join(os.getenv('SRC_DIR'), "data/prices_csv/stocks/*.csv"))
_logs.info(f'Found {len(stock_files)} stock price files.')

random.seed(42)
n_sample = 60
stock_files = random.sample(stock_files, n_sample)
_logs.info(f'Sampled {n_sample} stock price files for processing. The files are: {stock_files   }')
# Out:
# 2026-06-07 15:43:18,946, 3619788285.py, 2, INFO, Found 5884 stock price files.
# 2026-06-07 15:43:18,948, 3619788285.py, 7, INFO, Sampled 60 stock price files for processing. The files are: ['../../05_src/data/prices_csv/stocks/HCM.csv', '../../05_src/data/prices_csv/stocks/ATHM.csv', '../../05_src/data/prices_csv/stocks/RILYP.csv', '../../05_src/data/prices_csv/stocks/ALDX.csv', '../../05_src/data/prices_csv/stocks/JHG.csv', '../../05_src/data/prices_csv/stocks/CHRS.csv', '../../05_src/data/prices_csv/stocks/BKTI.csv', '../../05_src/data/prices_csv/stocks/REFR.csv', '../../05_src/data/prices_csv/stocks/KEN.csv', '../../05_src/data/prices_csv/stocks/MDRRP.csv', '../../05_src/data/prices_csv/stocks/GRF.csv', '../../05_src/data/prices_csv/stocks/KRC.csv', '../../05_src/data/prices_csv/stocks/MICT.csv', '../../05_src/data/prices_csv/stocks/AMPY.csv', '../../05_src/data/prices_csv/stocks/A.csv', '../../05_src/data/prices_csv/stocks/WRLSU.csv', '../../05_src/data/prices_csv/stocks/PNR.csv', '../../05_src/data/prices_csv/stocks/TERP.csv', '../../05_src/data/prices_csv/stocks/TMSR.csv', '../../05_src/data/prices_csv/stocks/TDJ.csv', '../../05_src/data/prices_csv/stocks/CIK.csv', '../../05_src/data/prices_csv/stocks/SMBC.csv', '../../05_src/data/prices_csv/stocks/CNSP.csv', '../../05_src/data/prices_csv/stocks/BLK.csv', '../../05_src/data/prices_csv/stocks/CLNC.csv', '../../05_src/data/prices_csv/stocks/AOSL.csv', '../../05_src/data/prices_csv/stocks/LYV.csv', '../../05_src/data/prices_csv/stocks/IX.csv', '../../05_src/data/prices_csv/stocks/AWRE.csv', '../../05_src/data/prices_csv/stocks/KNX.csv', '../../05_src/data/prices_csv/stocks/TRXC.csv', '../../05_src/data/prices_csv/stocks/CVCY.csv', '../../05_src/data/prices_csv/stocks/UVE.csv', '../../05_src/data/prices_csv/stocks/HCKT.csv', '../../05_src/data/prices_csv/stocks/TFSL.csv', '../../05_src/data/prices_csv/stocks/ACB.csv', '../../05_src/data/prices_csv/stocks/AXP.csv', '../../05_src/data/prices_csv/stocks/GLG.csv', '../../05_src/data/prices_csv/stocks/MFO.csv', '../../05_src/data/prices_csv/stocks/PCB.csv', '../../05_src/data/prices_csv/stocks/IPDN.csv', '../../05_src/data/prices_csv/stocks/DTW.csv', '../../05_src/data/prices_csv/stocks/IQV.csv', '../../05_src/data/prices_csv/stocks/EVRI.csv', '../../05_src/data/prices_csv/stocks/LIVE.csv', '../../05_src/data/prices_csv/stocks/KZR.csv', '../../05_src/data/prices_csv/stocks/SO.csv', '../../05_src/data/prices_csv/stocks/INFY.csv', '../../05_src/data/prices_csv/stocks/BSE.csv', '../../05_src/data/prices_csv/stocks/PSN.csv', '../../05_src/data/prices_csv/stocks/TNAV.csv', '../../05_src/data/prices_csv/stocks/APTX.csv', '../../05_src/data/prices_csv/stocks/LAZY.csv', '../../05_src/data/prices_csv/stocks/DK.csv', '../../05_src/data/prices_csv/stocks/ZEUS.csv', '../../05_src/data/prices_csv/stocks/IRBT.csv', '../../05_src/data/prices_csv/stocks/AMAT.csv', '../../05_src/data/prices_csv/stocks/PSB.csv', '../../05_src/data/prices_csv/stocks/CTSO.csv', '../../05_src/data/prices_csv/stocks/UEC.csv']

# %% [markdown]
# We load the sampled files into dataframes and concatenate them:
#
# + Start with an empty list.
# + Read each file into a dataframe and [`append()` it to the list](https://docs.python.org/3/tutorial/datastructures.html#more-on-lists). Notice that `append()` is an in-place operation (it does not return a list, it modifies the list in place).
# + Finally, we concatenate all dataframes along the vertical axis (`axis=0`) using [`pd.concat()`](https://pandas.pydata.org/docs/user_guide/merging.html#concat).
# + Notice that we do not concatenate each time that we load a dataframe. According to [Panda's documentation](https://pandas.pydata.org/docs/user_guide/merging.html#concat):
#
# > "`concat()` makes a full copy of the data, and iteratively reusing `concat()` can create unnecessary copies. Collect all DataFrame or Series objects in a list before using `concat()`."

# %%
dt_list = []
for s_file in stock_files:
    _logs.info(f"Reading file: {s_file}")
    dt = pd.read_csv(s_file).assign(
        source = os.path.basename(s_file),
        ticker = os.path.basename(s_file).replace('.csv', ''),
        Date = lambda x: pd.to_datetime(x['Date'])
    )
    dt_list.append(dt)
stock_prices = pd.concat(dt_list, axis = 0, ignore_index = True)
# Out:
# 2026-06-07 15:43:31,994, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/HCM.csv
# 2026-06-07 15:43:32,073, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/ATHM.csv
# 2026-06-07 15:43:32,084, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/RILYP.csv
# 2026-06-07 15:43:32,098, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/ALDX.csv
# 2026-06-07 15:43:32,118, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/JHG.csv
# 2026-06-07 15:43:32,132, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/CHRS.csv
# 2026-06-07 15:43:32,156, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/BKTI.csv
# 2026-06-07 15:43:32,203, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/REFR.csv
# 2026-06-07 15:43:32,241, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/KEN.csv
# 2026-06-07 15:43:32,255, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/MDRRP.csv
# 2026-06-07 15:43:32,263, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/GRF.csv
# 2026-06-07 15:43:32,330, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/KRC.csv
# 2026-06-07 15:43:32,370, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/MICT.csv
# 2026-06-07 15:43:32,386, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/AMPY.csv
# 2026-06-07 15:43:32,418, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/A.csv
# 2026-06-07 15:43:32,464, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/WRLSU.csv
# 2026-06-07 15:43:32,475, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/PNR.csv
# 2026-06-07 15:43:32,532, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/TERP.csv
# 2026-06-07 15:43:32,542, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/TMSR.csv
# 2026-06-07 15:43:32,556, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/TDJ.csv
# 2026-06-07 15:43:32,571, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/CIK.csv
# 2026-06-07 15:43:32,613, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/SMBC.csv
# 2026-06-07 15:43:32,646, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/CNSP.csv
# 2026-06-07 15:43:32,655, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/BLK.csv
# 2026-06-07 15:43:32,686, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/CLNC.csv
# 2026-06-07 15:43:32,694, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/AOSL.csv
# 2026-06-07 15:43:32,710, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/LYV.csv
# 2026-06-07 15:43:32,734, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/IX.csv
# 2026-06-07 15:43:32,784, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/AWRE.csv
# 2026-06-07 15:43:32,873, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/KNX.csv
# 2026-06-07 15:43:32,928, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/TRXC.csv
# 2026-06-07 15:43:32,994, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/CVCY.csv
# 2026-06-07 15:43:33,033, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/UVE.csv
# 2026-06-07 15:43:33,080, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/HCKT.csv
# 2026-06-07 15:43:33,165, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/TFSL.csv
# 2026-06-07 15:43:33,228, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/ACB.csv
# 2026-06-07 15:43:33,280, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/AXP.csv
# 2026-06-07 15:43:33,345, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/GLG.csv
# 2026-06-07 15:43:33,367, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/MFO.csv
# 2026-06-07 15:43:33,392, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/PCB.csv
# 2026-06-07 15:43:33,417, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/IPDN.csv
# 2026-06-07 15:43:33,461, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/DTW.csv
# 2026-06-07 15:43:33,538, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/IQV.csv
# 2026-06-07 15:43:33,559, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/EVRI.csv
# 2026-06-07 15:43:33,593, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/LIVE.csv
# 2026-06-07 15:43:33,635, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/KZR.csv
# 2026-06-07 15:43:33,659, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/SO.csv
# 2026-06-07 15:43:33,727, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/INFY.csv
# 2026-06-07 15:43:33,764, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/BSE.csv
# 2026-06-07 15:43:33,788, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/PSN.csv
# 2026-06-07 15:43:33,808, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/TNAV.csv
# 2026-06-07 15:43:33,833, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/APTX.csv
# 2026-06-07 15:43:33,843, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/LAZY.csv
# 2026-06-07 15:43:33,856, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/DK.csv
# 2026-06-07 15:43:33,881, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/ZEUS.csv
# 2026-06-07 15:43:33,926, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/IRBT.csv
# 2026-06-07 15:43:33,958, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/AMAT.csv
# 2026-06-07 15:43:34,023, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/PSB.csv
# 2026-06-07 15:43:34,064, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/CTSO.csv
# 2026-06-07 15:43:34,086, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/UEC.csv

# %% [markdown]
# Verify the structure of the `stock_prices` data using the [`info()` dataframe method](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.info.html):

# %%
stock_prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 230273 entries, 0 to 230272
# Data columns (total 9 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Date       230273 non-null  datetime64[ns]
#  1   Open       230260 non-null  float64
#  2   High       230260 non-null  float64
#  3   Low        230260 non-null  float64
#  4   Close      230260 non-null  float64
#  5   Adj Close  230260 non-null  float64
#  6   Volume     230260 non-null  float64
#  7   source     230273 non-null  object
#  8   ticker     230273 non-null  object
# dtypes: datetime64[ns](1), float64(6), object(2)
# memory usage: 15.8+ MB

# %% [markdown]
# We can subset our ticker data set using standard indexing techniques. Good references for this type of data manipulation are:
#
# + [Panda's Documentation](https://pandas.pydata.org/docs/user_guide/indexing.html#indexing-and-selecting-data).
# + [Panda's Cookbook](https://pandas.pydata.org/docs/user_guide/cookbook.html#cookbook-selection).

# %% [markdown]
# From the subset data frame, select one column and convert to list.

# %%
select_tickers = stock_prices['ticker'].unique().tolist()
select_tickers
# Out:
# ['HCM',
#  'ATHM',
#  'RILYP',
#  'ALDX',
#  'JHG',
#  'CHRS',
#  'BKTI',
#  'REFR',
#  'KEN',
#  'MDRRP',
#  'GRF',
#  'KRC',
#  'MICT',
#  'AMPY',
#  'A',
#  'WRLSU',
#  'PNR',
#  'TERP',
#  'TMSR',
#  'TDJ',
#  'CIK',
#  'SMBC',
#  'CNSP',
#  'BLK',
#  'CLNC',
#  'AOSL',
#  'LYV',
#  'IX',
#  'AWRE',
#  'KNX',
#  'TRXC',
#  'CVCY',
#  'UVE',
#  'HCKT',
#  'TFSL',
#  'ACB',
#  'AXP',
#  'GLG',
#  'MFO',
#  'PCB',
#  'IPDN',
#  'DTW',
#  'IQV',
#  'EVRI',
#  'LIVE',
#  'KZR',
#  'SO',
#  'INFY',
#  'BSE',
#  'PSN',
#  'TNAV',
#  'APTX',
#  'LAZY',
#  'DK',
#  'ZEUS',
#  'IRBT',
#  'AMAT',
#  'PSB',
#  'CTSO',
#  'UEC']

# %% [markdown]
# # Storing Data in CSV
#
# + We have some data. How do we store it?
# + We can compare two options, CSV and Parquet, by measuring their performance:
#
#     - Time to save: We will measure time by using the `time` library.
#     - Space required on drive: We will use the custom function below.

# %%
def get_dir_size(path='.'):
    '''Returns the total size of files contained in path.'''
    total = 0
    with os.scandir(path) as it:
        for entry in it:
            if entry.is_file():
                total += entry.stat().st_size
            elif entry.is_dir():
                total += get_dir_size(entry.path)
    return total

# %% [markdown]
# Load the specification of a temporary directory from the environment  and create a subdirectory in it called "csv":
#
# + Use `os.getenv("TEMP_DATA")` to obtain the desired location of the temporary folder from an environment variable.
# + If the subdirectory exists, delete it using `shutil.rmtree()`; the flag `ignore_errors=True` helps us in case the subdirectory does not exist (for instance, in the first run).
# + Create a directory with path given by `csv_dir` using `os.makedirs()`; the flag `exist_ok=True` indicates that if the directory already exists, then the function will do nothing.
# + Finally, create the stock price file location, `stock_csv`, which will be used to create the csv file.

# %%
import shutil

temp = os.getenv("TEMP_DATA")
csv_dir = os.path.join(temp, "csv")

shutil.rmtree(csv_dir, ignore_errors=True)
os.makedirs(csv_dir, exist_ok=True)
stock_csv = os.path.join(csv_dir, "stock_px.csv")

# %% [markdown]
# Save the concatenated dataframe to a CSV file. We measure the time elapsed by storing the start and end times, then we calculate their difference in seconds.

# %%
import time

start = time.time()
stock_prices.to_csv(stock_csv, index = False)
end = time.time()

_logs.info(f'Writing data ({stock_prices.shape}) to csv took {end - start} seconds.')
_logs.info(f'CSV file size { os.path.getsize(stock_csv)*1e-6 } MB')
# Out:
# 2026-06-07 15:43:54,801, 807204384.py, 7, INFO, Writing data ((230273, 9)) to csv took 2.3596081733703613 seconds.
# 2026-06-07 15:43:54,802, 807204384.py, 8, INFO, CSV file size 25.944855999999998 MB

# %% [markdown]
# ## Save Data to Parquet
#
# ### Notes on Dask
#
# We could use Pandas to save the data directly into Parquet files. However, we will use a different approach by applying the [Dask framework](https://www.dask.org/). Dask provides functionality for working with datasets that do not fit in memory and parallelization to speed up computation. A few notes on Dask and Pandas:
#
# - Pandas, Parquet, and Arrow:
#
#     + We can work with large datasets and Parquet files in Pandas, but we will generally be limited by the amount of data that can fit in our computer's memory.
#     + Pandas can write Parquet files using a PyArrow backend. In fact, recent versions of Pandas support PyArrow data types, and future versions will require a PyArrow backend.
#     + The PyArrow library is an interface between Python and the Apache Arrow project. In particular, the [Parquet data format](https://parquet.apache.org/) and [Arrow](https://arrow.apache.org/docs/python/parquet.html) are Apache projects.
#
# - Dask
#
#     + Dask is much more than an interface to Arrow: Dask provides parallel and distributed computing on Pandas-like dataframes.
#     + Dask is also relatively easy to use as it mimics Pandas' API.
#     + Dask allows us to work with larger datasets than Pandas. In a sense, it is an intermediate step between Pandas and big-data frameworks like Spark (or Databricks).
#     + If you are familiar with Pandas, a good introduction is [10 Minutes to Dask](https://docs.dask.org/en/stable/10-minutes-to-dask.html).

# %%
import dask.dataframe as dd

parquet_dir = os.path.join(temp, "parquet")
shutil.rmtree(parquet_dir, ignore_errors=True)
os.makedirs(parquet_dir, exist_ok=True)

# %%
px_dd = dd.from_pandas(stock_prices, npartitions = len(select_tickers))

start = time.time()
px_dd.to_parquet(parquet_dir, engine = "pyarrow")
end = time.time()

_logs.info(f'Writing dd ({stock_prices.shape}) to parquet took {end - start} seconds.')
_logs.info(f'Parquet file size { get_dir_size(parquet_dir)*1e-6 } MB')
# Out:
# 2026-06-07 15:44:16,459, 817812245.py, 7, INFO, Writing dd ((230273, 9)) to parquet took 0.8048560619354248 seconds.
# 2026-06-07 15:44:16,462, 817812245.py, 8, INFO, Parquet file size 8.886884 MB

# %% [markdown]
# ### Pandas, Dask, and Parquet
#
# The distinction of Pandas Dataframes, Dask Dataframes, and Parquet files is important:
#
# + Pandas dataframes combine the functionality of [NumPy](https://numpy.org/) (efficient vector operations, especially vector algebra) with a concise data manipulation framework that allows us to create columns of different data types (NumPy only allows single-type matrices), database-like operations (such as filtering rows, subsetting columns, and joining different dataframes).
# + Dask dataframes extend the functionality of Pandas dataframes beyond the confines of available memory and implement parallelized operations, among other benefits.
# + Parquet files are a file format. Parquet files can be created by Pandas and Dask, but Dask offers a superior interface. Parquet files are immutable: once written, they cannot be modified.
# + Parquet and Dask are not the same: Parquet is a file format that can be accessed by many applications and programming languages (Python, R, Power BI, etc.), while Dask is a Python package for working with large datasets using distributed computation.

# %% [markdown]
# ### Dask is Powerful, but not Infallible
#
# It is tempting to think of Dask as a super-Pandas, but each package has its advantages and disadvantages.
#
# + Dask is not good at everything (see [Dask DataFrames Best Practices](https://docs.dask.org/en/stable/dataframe-best-practices.html)).
# + A useful and somewhat idiosyncratic comparison of various data manipulation frameworks is shown below (from [DataFrames at Scale Comparison: TPC-H](https://docs.coiled.io/blog/tpch.html#when-to-use-duckdb-vs-polars-vs-dask-vs-spark))
#
# Concept              | Spark | Dask | DuckDB | Polars
# ---------------------|-------|------|--------|--------
# Fast Locally         | ❌    | 🤔  | ✅     | ✅
# Fast on Cloud (1 TB) | ✅    | ✅  | ✅     | ❌
# Fast on Cloud (10 TB)| ❌    | ✅  | ✅     | ❌
# Scales Out           | ✅    | ✅  | ❌     | ❌
# SQL                  | ✅    | 🤔  | ✅     | 🤔
# More than SQL        | ✅    | ✅  | ❌     | ✅
# Sensible Defaults    | ❌    | ✅  | ✅     | ✅
#
#
# ### Dask Best Practices
#
# Parallelism brings extra complexity and overhead. Here are a few ideas to help you decide when to use Dask (from [Dask's Best Practices](https://docs.dask.org/en/stable/best-practices.html)):
#
# #### Small is Better
#
# + Start small: if possible, use Pandas. Also, try to reduce your data using aggregation, then use Pandas.
# + More generally, NumPy, Pandas, and Scikit-Learn may have faster functions for what you need. Consult the relevant documentation, experiment, and/or consult with a colleague or expert.
#
# #### Index with Care
#
# + Use the index: it is beneficial to have a well-defined index in Dask DataFrames, as it may speed up searching (filtering) the data. A one-dimensional index is allowed.
# + Minimize full-data shuffling as much as possible: indexing is an expensive operation.
#
# ### Consider the Cost of Joins
#
# + Consider cases such as small-to-large joins, where the small dataframe fits in memory, but the large one does not. The small dataframe can be Pandas, while the larger one is a Dask dataframe.
# + Some joins are more expensive than others.
#
#     * Not expensive:
#
#         - Join a Dask DataFrame with a Pandas DataFrame.
#         - Join a Dask DataFrame with another Dask DataFrame of a single partition.
#         - Join Dask DataFrames along their indexes.
#
#     * Expensive:
#
#         - Join Dask DataFrames along columns that are not their index.

# %% [markdown]
# # How Do We Store Prices?
#
# + We can store our data as a single blob.
#
#   - This can be difficult to maintain, especially because parquet files are immutable.
#   - Using a single file, we would need to recreate the complete file any time that we update it.
#
# + An alternative strategy is to organize data files by ticker and date:
#
#   - We can create one file per ticker and month (or any other suitable frequency).
#   - Under this approach, we would only need to recreate the latest month's file at any update.

# %%
# Clean up before start
PRICE_DATA = os.getenv("PRICE_DATA")
import shutil
if os.path.exists(PRICE_DATA):
    shutil.rmtree(PRICE_DATA)

# %%
stock_prices.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', 'source',
#        'ticker'],
#       dtype='object')

# %%
for ticker in stock_prices['ticker'].unique():
    # Filter data for ticker
    # Notice that these are Pandas dataframes
    _logs.info(f'Processing ticker: {ticker}')
    ticker_dt = stock_prices[stock_prices['ticker'] == ticker]
    ticker_dt = ticker_dt.assign(Year = ticker_dt.Date.dt.year)
    for yr in ticker_dt['Year'].unique():
        _logs.info(f'Processing year {yr} for ticker {ticker}.')
        # Filter data for year and convert to Dask dataframe
        yr_dd = dd.from_pandas(ticker_dt[ticker_dt['Year'] == yr],2)
        
        # Define path and create directories if not exist
        yr_path = os.path.join(PRICE_DATA, ticker, f"{ticker}_{yr}")
        os.makedirs(os.path.dirname(yr_path), exist_ok=True)
        _logs.info(f'Writing data to path: {yr_path}')

        # Write to Parquet
        yr_dd.to_parquet(yr_path, engine = "pyarrow")
# Out:
# 2026-06-07 15:44:36,656, 2113979629.py, 4, INFO, Processing ticker: HCM
# 2026-06-07 15:44:36,701, 2113979629.py, 8, INFO, Processing year 2016 for ticker HCM.
# 2026-06-07 15:44:36,723, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/HCM/HCM_2016
# 2026-06-07 15:44:36,770, 2113979629.py, 8, INFO, Processing year 2017 for ticker HCM.
# 2026-06-07 15:44:36,784, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/HCM/HCM_2017
# 2026-06-07 15:44:36,809, 2113979629.py, 8, INFO, Processing year 2018 for ticker HCM.
# 2026-06-07 15:44:36,819, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/HCM/HCM_2018
# 2026-06-07 15:44:36,855, 2113979629.py, 8, INFO, Processing year 2019 for ticker HCM.
# 2026-06-07 15:44:36,871, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/HCM/HCM_2019
# 2026-06-07 15:44:36,922, 2113979629.py, 8, INFO, Processing year 2020 for ticker HCM.
# 2026-06-07 15:44:36,932, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/HCM/HCM_2020
# 2026-06-07 15:44:36,966, 2113979629.py, 4, INFO, Processing ticker: ATHM
# 2026-06-07 15:44:36,992, 2113979629.py, 8, INFO, Processing year 2013 for ticker ATHM.
# 2026-06-07 15:44:37,003, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ATHM/ATHM_2013
# 2026-06-07 15:44:37,055, 2113979629.py, 8, INFO, Processing year 2014 for ticker ATHM.
# 2026-06-07 15:44:37,065, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ATHM/ATHM_2014
# 2026-06-07 15:44:37,120, 2113979629.py, 8, INFO, Processing year 2015 for ticker ATHM.
# 2026-06-07 15:44:37,133, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ATHM/ATHM_2015
# 2026-06-07 15:44:37,179, 2113979629.py, 8, INFO, Processing year 2016 for ticker ATHM.
# 2026-06-07 15:44:37,193, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ATHM/ATHM_2016
# 2026-06-07 15:44:37,227, 2113979629.py, 8, INFO, Processing year 2017 for ticker ATHM.
# 2026-06-07 15:44:37,241, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ATHM/ATHM_2017
# 2026-06-07 15:44:37,303, 2113979629.py, 8, INFO, Processing year 2018 for ticker ATHM.
# 2026-06-07 15:44:37,336, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ATHM/ATHM_2018
# 2026-06-07 15:44:37,438, 2113979629.py, 8, INFO, Processing year 2019 for ticker ATHM.
# 2026-06-07 15:44:37,462, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ATHM/ATHM_2019
# 2026-06-07 15:44:37,552, 2113979629.py, 8, INFO, Processing year 2020 for ticker ATHM.
# 2026-06-07 15:44:37,571, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ATHM/ATHM_2020
# 2026-06-07 15:44:37,690, 2113979629.py, 4, INFO, Processing ticker: RILYP
# 2026-06-07 15:44:37,725, 2113979629.py, 8, INFO, Processing year 2020 for ticker RILYP.
# 2026-06-07 15:44:37,751, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/RILYP/RILYP_2020
# 2026-06-07 15:44:37,830, 2113979629.py, 4, INFO, Processing ticker: ALDX
# 2026-06-07 15:44:37,898, 2113979629.py, 8, INFO, Processing year 2014 for ticker ALDX.
# 2026-06-07 15:44:37,924, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ALDX/ALDX_2014
# 2026-06-07 15:44:38,004, 2113979629.py, 8, INFO, Processing year 2015 for ticker ALDX.
# 2026-06-07 15:44:38,018, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ALDX/ALDX_2015
# 2026-06-07 15:44:38,076, 2113979629.py, 8, INFO, Processing year 2016 for ticker ALDX.
# 2026-06-07 15:44:38,090, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ALDX/ALDX_2016
# 2026-06-07 15:44:38,137, 2113979629.py, 8, INFO, Processing year 2017 for ticker ALDX.
# 2026-06-07 15:44:38,147, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ALDX/ALDX_2017
# 2026-06-07 15:44:38,184, 2113979629.py, 8, INFO, Processing year 2018 for ticker ALDX.
# 2026-06-07 15:44:38,194, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ALDX/ALDX_2018
# 2026-06-07 15:44:38,248, 2113979629.py, 8, INFO, Processing year 2019 for ticker ALDX.
# 2026-06-07 15:44:38,259, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ALDX/ALDX_2019
# 2026-06-07 15:44:38,302, 2113979629.py, 8, INFO, Processing year 2020 for ticker ALDX.
# 2026-06-07 15:44:38,312, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ALDX/ALDX_2020
# 2026-06-07 15:44:38,356, 2113979629.py, 4, INFO, Processing ticker: JHG
# 2026-06-07 15:44:38,380, 2113979629.py, 8, INFO, Processing year 2017 for ticker JHG.
# 2026-06-07 15:44:38,389, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/JHG/JHG_2017
# 2026-06-07 15:44:38,430, 2113979629.py, 8, INFO, Processing year 2018 for ticker JHG.
# 2026-06-07 15:44:38,442, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/JHG/JHG_2018
# 2026-06-07 15:44:38,478, 2113979629.py, 8, INFO, Processing year 2019 for ticker JHG.
# 2026-06-07 15:44:38,492, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/JHG/JHG_2019
# 2026-06-07 15:44:38,543, 2113979629.py, 8, INFO, Processing year 2020 for ticker JHG.
# 2026-06-07 15:44:38,557, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/JHG/JHG_2020
# 2026-06-07 15:44:38,615, 2113979629.py, 4, INFO, Processing ticker: CHRS
# 2026-06-07 15:44:38,644, 2113979629.py, 8, INFO, Processing year 2001 for ticker CHRS.
# 2026-06-07 15:44:38,652, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CHRS/CHRS_2001
# 2026-06-07 15:44:38,689, 2113979629.py, 8, INFO, Processing year 2002 for ticker CHRS.
# 2026-06-07 15:44:38,696, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CHRS/CHRS_2002
# 2026-06-07 15:44:38,725, 2113979629.py, 8, INFO, Processing year 2003 for ticker CHRS.
# 2026-06-07 15:44:38,736, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CHRS/CHRS_2003
# 2026-06-07 15:44:38,775, 2113979629.py, 8, INFO, Processing year 2005 for ticker CHRS.
# 2026-06-07 15:44:38,788, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CHRS/CHRS_2005
# 2026-06-07 15:44:38,823, 2113979629.py, 8, INFO, Processing year 2006 for ticker CHRS.
# 2026-06-07 15:44:38,834, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CHRS/CHRS_2006
# 2026-06-07 15:44:38,867, 2113979629.py, 8, INFO, Processing year 2007 for ticker CHRS.
# 2026-06-07 15:44:38,874, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CHRS/CHRS_2007
# 2026-06-07 15:44:38,908, 2113979629.py, 8, INFO, Processing year 2008 for ticker CHRS.
# 2026-06-07 15:44:38,915, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CHRS/CHRS_2008
# 2026-06-07 15:44:39,004, 2113979629.py, 8, INFO, Processing year 2011 for ticker CHRS.
# 2026-06-07 15:44:39,010, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CHRS/CHRS_2011
# 2026-06-07 15:44:39,041, 2113979629.py, 8, INFO, Processing year 2012 for ticker CHRS.
# 2026-06-07 15:44:39,047, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CHRS/CHRS_2012
# 2026-06-07 15:44:39,082, 2113979629.py, 8, INFO, Processing year 2013 for ticker CHRS.
# 2026-06-07 15:44:39,093, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CHRS/CHRS_2013
# 2026-06-07 15:44:39,127, 2113979629.py, 8, INFO, Processing year 2014 for ticker CHRS.
# 2026-06-07 15:44:39,137, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CHRS/CHRS_2014
# 2026-06-07 15:44:39,166, 2113979629.py, 8, INFO, Processing year 2015 for ticker CHRS.
# 2026-06-07 15:44:39,176, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CHRS/CHRS_2015
# 2026-06-07 15:44:39,211, 2113979629.py, 8, INFO, Processing year 2016 for ticker CHRS.
# 2026-06-07 15:44:39,219, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CHRS/CHRS_2016
# 2026-06-07 15:44:39,257, 2113979629.py, 8, INFO, Processing year 2017 for ticker CHRS.
# 2026-06-07 15:44:39,266, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CHRS/CHRS_2017
# 2026-06-07 15:44:39,310, 2113979629.py, 8, INFO, Processing year 2018 for ticker CHRS.
# 2026-06-07 15:44:39,319, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CHRS/CHRS_2018
# 2026-06-07 15:44:39,354, 2113979629.py, 8, INFO, Processing year 2019 for ticker CHRS.
# 2026-06-07 15:44:39,363, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CHRS/CHRS_2019
# 2026-06-07 15:44:39,396, 2113979629.py, 8, INFO, Processing year 2020 for ticker CHRS.
# 2026-06-07 15:44:39,404, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CHRS/CHRS_2020
# 2026-06-07 15:44:39,436, 2113979629.py, 4, INFO, Processing ticker: BKTI
# 2026-06-07 15:44:39,461, 2113979629.py, 8, INFO, Processing year 1980 for ticker BKTI.
# 2026-06-07 15:44:39,469, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_1980
# 2026-06-07 15:44:39,503, 2113979629.py, 8, INFO, Processing year 1981 for ticker BKTI.
# 2026-06-07 15:44:39,511, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_1981
# 2026-06-07 15:44:39,545, 2113979629.py, 8, INFO, Processing year 1982 for ticker BKTI.
# 2026-06-07 15:44:39,554, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_1982
# 2026-06-07 15:44:39,593, 2113979629.py, 8, INFO, Processing year 1983 for ticker BKTI.
# 2026-06-07 15:44:39,603, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_1983
# 2026-06-07 15:44:39,641, 2113979629.py, 8, INFO, Processing year 1984 for ticker BKTI.
# 2026-06-07 15:44:39,649, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_1984
# 2026-06-07 15:44:39,684, 2113979629.py, 8, INFO, Processing year 1985 for ticker BKTI.
# 2026-06-07 15:44:39,693, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_1985
# 2026-06-07 15:44:39,723, 2113979629.py, 8, INFO, Processing year 1986 for ticker BKTI.
# 2026-06-07 15:44:39,733, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_1986
# 2026-06-07 15:44:39,768, 2113979629.py, 8, INFO, Processing year 1987 for ticker BKTI.
# 2026-06-07 15:44:39,777, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_1987
# 2026-06-07 15:44:39,812, 2113979629.py, 8, INFO, Processing year 1988 for ticker BKTI.
# 2026-06-07 15:44:39,823, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_1988
# 2026-06-07 15:44:39,860, 2113979629.py, 8, INFO, Processing year 1989 for ticker BKTI.
# 2026-06-07 15:44:39,869, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_1989
# 2026-06-07 15:44:39,904, 2113979629.py, 8, INFO, Processing year 1990 for ticker BKTI.
# 2026-06-07 15:44:39,914, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_1990
# 2026-06-07 15:44:39,949, 2113979629.py, 8, INFO, Processing year 1991 for ticker BKTI.
# 2026-06-07 15:44:39,958, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_1991
# 2026-06-07 15:44:39,989, 2113979629.py, 8, INFO, Processing year 1992 for ticker BKTI.
# 2026-06-07 15:44:39,998, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_1992
# 2026-06-07 15:44:40,035, 2113979629.py, 8, INFO, Processing year 1993 for ticker BKTI.
# 2026-06-07 15:44:40,044, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_1993
# 2026-06-07 15:44:40,100, 2113979629.py, 8, INFO, Processing year 1994 for ticker BKTI.
# 2026-06-07 15:44:40,118, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_1994
# 2026-06-07 15:44:40,155, 2113979629.py, 8, INFO, Processing year 1995 for ticker BKTI.
# 2026-06-07 15:44:40,164, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_1995
# 2026-06-07 15:44:40,199, 2113979629.py, 8, INFO, Processing year 1996 for ticker BKTI.
# 2026-06-07 15:44:40,207, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_1996
# 2026-06-07 15:44:40,235, 2113979629.py, 8, INFO, Processing year 1997 for ticker BKTI.
# 2026-06-07 15:44:40,244, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_1997
# 2026-06-07 15:44:40,276, 2113979629.py, 8, INFO, Processing year 1998 for ticker BKTI.
# 2026-06-07 15:44:40,286, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_1998
# 2026-06-07 15:44:40,316, 2113979629.py, 8, INFO, Processing year 1999 for ticker BKTI.
# 2026-06-07 15:44:40,324, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_1999
# 2026-06-07 15:44:40,354, 2113979629.py, 8, INFO, Processing year 2000 for ticker BKTI.
# 2026-06-07 15:44:40,363, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2000
# 2026-06-07 15:44:40,398, 2113979629.py, 8, INFO, Processing year 2001 for ticker BKTI.
# 2026-06-07 15:44:40,407, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2001
# 2026-06-07 15:44:40,445, 2113979629.py, 8, INFO, Processing year 2002 for ticker BKTI.
# 2026-06-07 15:44:40,453, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2002
# 2026-06-07 15:44:40,489, 2113979629.py, 8, INFO, Processing year 2003 for ticker BKTI.
# 2026-06-07 15:44:40,498, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2003
# 2026-06-07 15:44:40,541, 2113979629.py, 8, INFO, Processing year 2004 for ticker BKTI.
# 2026-06-07 15:44:40,552, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2004
# 2026-06-07 15:44:40,603, 2113979629.py, 8, INFO, Processing year 2005 for ticker BKTI.
# 2026-06-07 15:44:40,620, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2005
# 2026-06-07 15:44:40,678, 2113979629.py, 8, INFO, Processing year 2006 for ticker BKTI.
# 2026-06-07 15:44:40,691, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2006
# 2026-06-07 15:44:40,736, 2113979629.py, 8, INFO, Processing year 2007 for ticker BKTI.
# 2026-06-07 15:44:40,746, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2007
# 2026-06-07 15:44:40,804, 2113979629.py, 8, INFO, Processing year 2008 for ticker BKTI.
# 2026-06-07 15:44:40,814, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2008
# 2026-06-07 15:44:40,861, 2113979629.py, 8, INFO, Processing year 2009 for ticker BKTI.
# 2026-06-07 15:44:40,872, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2009
# 2026-06-07 15:44:40,909, 2113979629.py, 8, INFO, Processing year 2010 for ticker BKTI.
# 2026-06-07 15:44:40,919, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2010
# 2026-06-07 15:44:40,950, 2113979629.py, 8, INFO, Processing year 2011 for ticker BKTI.
# 2026-06-07 15:44:40,960, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2011
# 2026-06-07 15:44:40,996, 2113979629.py, 8, INFO, Processing year 2012 for ticker BKTI.
# 2026-06-07 15:44:41,005, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2012
# 2026-06-07 15:44:41,041, 2113979629.py, 8, INFO, Processing year 2013 for ticker BKTI.
# 2026-06-07 15:44:41,050, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2013
# 2026-06-07 15:44:41,080, 2113979629.py, 8, INFO, Processing year 2014 for ticker BKTI.
# 2026-06-07 15:44:41,090, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2014
# 2026-06-07 15:44:41,121, 2113979629.py, 8, INFO, Processing year 2015 for ticker BKTI.
# 2026-06-07 15:44:41,130, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2015
# 2026-06-07 15:44:41,164, 2113979629.py, 8, INFO, Processing year 2016 for ticker BKTI.
# 2026-06-07 15:44:41,174, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2016
# 2026-06-07 15:44:41,209, 2113979629.py, 8, INFO, Processing year 2017 for ticker BKTI.
# 2026-06-07 15:44:41,218, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2017
# 2026-06-07 15:44:41,253, 2113979629.py, 8, INFO, Processing year 2018 for ticker BKTI.
# 2026-06-07 15:44:41,262, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2018
# 2026-06-07 15:44:41,296, 2113979629.py, 8, INFO, Processing year 2019 for ticker BKTI.
# 2026-06-07 15:44:41,305, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2019
# 2026-06-07 15:44:41,332, 2113979629.py, 8, INFO, Processing year 2020 for ticker BKTI.
# 2026-06-07 15:44:41,343, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2020
# 2026-06-07 15:44:41,375, 2113979629.py, 4, INFO, Processing ticker: REFR
# 2026-06-07 15:44:41,402, 2113979629.py, 8, INFO, Processing year 1993 for ticker REFR.
# 2026-06-07 15:44:41,410, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_1993
# 2026-06-07 15:44:41,447, 2113979629.py, 8, INFO, Processing year 1994 for ticker REFR.
# 2026-06-07 15:44:41,458, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_1994
# 2026-06-07 15:44:41,492, 2113979629.py, 8, INFO, Processing year 1995 for ticker REFR.
# 2026-06-07 15:44:41,501, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_1995
# 2026-06-07 15:44:41,532, 2113979629.py, 8, INFO, Processing year 1996 for ticker REFR.
# 2026-06-07 15:44:41,541, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_1996
# 2026-06-07 15:44:41,568, 2113979629.py, 8, INFO, Processing year 1997 for ticker REFR.
# 2026-06-07 15:44:41,580, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_1997
# 2026-06-07 15:44:41,617, 2113979629.py, 8, INFO, Processing year 1998 for ticker REFR.
# 2026-06-07 15:44:41,628, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_1998
# 2026-06-07 15:44:41,665, 2113979629.py, 8, INFO, Processing year 1999 for ticker REFR.
# 2026-06-07 15:44:41,677, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_1999
# 2026-06-07 15:44:41,711, 2113979629.py, 8, INFO, Processing year 2000 for ticker REFR.
# 2026-06-07 15:44:41,720, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2000
# 2026-06-07 15:44:41,755, 2113979629.py, 8, INFO, Processing year 2001 for ticker REFR.
# 2026-06-07 15:44:41,761, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2001
# 2026-06-07 15:44:41,794, 2113979629.py, 8, INFO, Processing year 2002 for ticker REFR.
# 2026-06-07 15:44:41,802, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2002
# 2026-06-07 15:44:41,831, 2113979629.py, 8, INFO, Processing year 2003 for ticker REFR.
# 2026-06-07 15:44:41,843, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2003
# 2026-06-07 15:44:41,873, 2113979629.py, 8, INFO, Processing year 2004 for ticker REFR.
# 2026-06-07 15:44:41,882, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2004
# 2026-06-07 15:44:41,947, 2113979629.py, 8, INFO, Processing year 2005 for ticker REFR.
# 2026-06-07 15:44:41,957, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2005
# 2026-06-07 15:44:41,996, 2113979629.py, 8, INFO, Processing year 2006 for ticker REFR.
# 2026-06-07 15:44:42,007, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2006
# 2026-06-07 15:44:42,044, 2113979629.py, 8, INFO, Processing year 2007 for ticker REFR.
# 2026-06-07 15:44:42,052, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2007
# 2026-06-07 15:44:42,087, 2113979629.py, 8, INFO, Processing year 2008 for ticker REFR.
# 2026-06-07 15:44:42,094, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2008
# 2026-06-07 15:44:42,122, 2113979629.py, 8, INFO, Processing year 2009 for ticker REFR.
# 2026-06-07 15:44:42,131, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2009
# 2026-06-07 15:44:42,164, 2113979629.py, 8, INFO, Processing year 2010 for ticker REFR.
# 2026-06-07 15:44:42,172, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2010
# 2026-06-07 15:44:42,208, 2113979629.py, 8, INFO, Processing year 2011 for ticker REFR.
# 2026-06-07 15:44:42,218, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2011
# 2026-06-07 15:44:42,252, 2113979629.py, 8, INFO, Processing year 2012 for ticker REFR.
# 2026-06-07 15:44:42,259, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2012
# 2026-06-07 15:44:42,289, 2113979629.py, 8, INFO, Processing year 2013 for ticker REFR.
# 2026-06-07 15:44:42,297, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2013
# 2026-06-07 15:44:42,424, 2113979629.py, 8, INFO, Processing year 2014 for ticker REFR.
# 2026-06-07 15:44:42,442, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2014
# 2026-06-07 15:44:42,505, 2113979629.py, 8, INFO, Processing year 2015 for ticker REFR.
# 2026-06-07 15:44:42,512, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2015
# 2026-06-07 15:44:42,548, 2113979629.py, 8, INFO, Processing year 2016 for ticker REFR.
# 2026-06-07 15:44:42,556, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2016
# 2026-06-07 15:44:42,590, 2113979629.py, 8, INFO, Processing year 2017 for ticker REFR.
# 2026-06-07 15:44:42,598, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2017
# 2026-06-07 15:44:42,623, 2113979629.py, 8, INFO, Processing year 2018 for ticker REFR.
# 2026-06-07 15:44:42,634, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2018
# 2026-06-07 15:44:42,665, 2113979629.py, 8, INFO, Processing year 2019 for ticker REFR.
# 2026-06-07 15:44:42,673, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2019
# 2026-06-07 15:44:42,712, 2113979629.py, 8, INFO, Processing year 2020 for ticker REFR.
# 2026-06-07 15:44:42,724, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2020
# 2026-06-07 15:44:42,765, 2113979629.py, 4, INFO, Processing ticker: KEN
# 2026-06-07 15:44:42,794, 2113979629.py, 8, INFO, Processing year 2015 for ticker KEN.
# 2026-06-07 15:44:42,801, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEN/KEN_2015
# 2026-06-07 15:44:42,837, 2113979629.py, 8, INFO, Processing year 2016 for ticker KEN.
# 2026-06-07 15:44:42,845, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEN/KEN_2016
# 2026-06-07 15:44:42,876, 2113979629.py, 8, INFO, Processing year 2017 for ticker KEN.
# 2026-06-07 15:44:42,888, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEN/KEN_2017
# 2026-06-07 15:44:42,918, 2113979629.py, 8, INFO, Processing year 2018 for ticker KEN.
# 2026-06-07 15:44:42,931, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEN/KEN_2018
# 2026-06-07 15:44:42,970, 2113979629.py, 8, INFO, Processing year 2019 for ticker KEN.
# 2026-06-07 15:44:42,982, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEN/KEN_2019
# 2026-06-07 15:44:43,019, 2113979629.py, 8, INFO, Processing year 2020 for ticker KEN.
# 2026-06-07 15:44:43,027, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEN/KEN_2020
# 2026-06-07 15:44:43,058, 2113979629.py, 4, INFO, Processing ticker: MDRRP
# 2026-06-07 15:44:43,078, 2113979629.py, 8, INFO, Processing year 2020 for ticker MDRRP.
# 2026-06-07 15:44:43,089, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MDRRP/MDRRP_2020
# 2026-06-07 15:44:43,124, 2113979629.py, 4, INFO, Processing ticker: GRF
# 2026-06-07 15:44:43,151, 2113979629.py, 8, INFO, Processing year 2004 for ticker GRF.
# 2026-06-07 15:44:43,158, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GRF/GRF_2004
# 2026-06-07 15:44:43,198, 2113979629.py, 8, INFO, Processing year 2005 for ticker GRF.
# 2026-06-07 15:44:43,207, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GRF/GRF_2005
# 2026-06-07 15:44:43,241, 2113979629.py, 8, INFO, Processing year 2006 for ticker GRF.
# 2026-06-07 15:44:43,250, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GRF/GRF_2006
# 2026-06-07 15:44:43,288, 2113979629.py, 8, INFO, Processing year 2007 for ticker GRF.
# 2026-06-07 15:44:43,297, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GRF/GRF_2007
# 2026-06-07 15:44:43,331, 2113979629.py, 8, INFO, Processing year 2008 for ticker GRF.
# 2026-06-07 15:44:43,340, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GRF/GRF_2008
# 2026-06-07 15:44:43,369, 2113979629.py, 8, INFO, Processing year 2009 for ticker GRF.
# 2026-06-07 15:44:43,377, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GRF/GRF_2009
# 2026-06-07 15:44:43,408, 2113979629.py, 8, INFO, Processing year 2010 for ticker GRF.
# 2026-06-07 15:44:43,417, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GRF/GRF_2010
# 2026-06-07 15:44:43,449, 2113979629.py, 8, INFO, Processing year 2011 for ticker GRF.
# 2026-06-07 15:44:43,456, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GRF/GRF_2011
# 2026-06-07 15:44:43,491, 2113979629.py, 8, INFO, Processing year 2012 for ticker GRF.
# 2026-06-07 15:44:43,501, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GRF/GRF_2012
# 2026-06-07 15:44:43,533, 2113979629.py, 8, INFO, Processing year 2013 for ticker GRF.
# 2026-06-07 15:44:43,544, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GRF/GRF_2013
# 2026-06-07 15:44:43,579, 2113979629.py, 8, INFO, Processing year 2014 for ticker GRF.
# 2026-06-07 15:44:43,590, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GRF/GRF_2014
# 2026-06-07 15:44:43,645, 2113979629.py, 8, INFO, Processing year 2015 for ticker GRF.
# 2026-06-07 15:44:43,655, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GRF/GRF_2015
# 2026-06-07 15:44:43,697, 2113979629.py, 8, INFO, Processing year 2016 for ticker GRF.
# 2026-06-07 15:44:43,707, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GRF/GRF_2016
# 2026-06-07 15:44:43,741, 2113979629.py, 8, INFO, Processing year 2017 for ticker GRF.
# 2026-06-07 15:44:43,750, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GRF/GRF_2017
# 2026-06-07 15:44:43,784, 2113979629.py, 8, INFO, Processing year 2018 for ticker GRF.
# 2026-06-07 15:44:43,792, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GRF/GRF_2018
# 2026-06-07 15:44:43,827, 2113979629.py, 8, INFO, Processing year 2019 for ticker GRF.
# 2026-06-07 15:44:43,837, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GRF/GRF_2019
# 2026-06-07 15:44:43,864, 2113979629.py, 8, INFO, Processing year 2020 for ticker GRF.
# 2026-06-07 15:44:43,876, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GRF/GRF_2020
# 2026-06-07 15:44:43,917, 2113979629.py, 4, INFO, Processing ticker: KRC
# 2026-06-07 15:44:43,944, 2113979629.py, 8, INFO, Processing year 1997 for ticker KRC.
# 2026-06-07 15:44:43,953, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_1997
# 2026-06-07 15:44:43,989, 2113979629.py, 8, INFO, Processing year 1998 for ticker KRC.
# 2026-06-07 15:44:43,998, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_1998
# 2026-06-07 15:44:44,035, 2113979629.py, 8, INFO, Processing year 1999 for ticker KRC.
# 2026-06-07 15:44:44,045, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_1999
# 2026-06-07 15:44:44,079, 2113979629.py, 8, INFO, Processing year 2000 for ticker KRC.
# 2026-06-07 15:44:44,090, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2000
# 2026-06-07 15:44:44,124, 2113979629.py, 8, INFO, Processing year 2001 for ticker KRC.
# 2026-06-07 15:44:44,133, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2001
# 2026-06-07 15:44:44,165, 2113979629.py, 8, INFO, Processing year 2002 for ticker KRC.
# 2026-06-07 15:44:44,177, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2002
# 2026-06-07 15:44:44,216, 2113979629.py, 8, INFO, Processing year 2003 for ticker KRC.
# 2026-06-07 15:44:44,225, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2003
# 2026-06-07 15:44:44,266, 2113979629.py, 8, INFO, Processing year 2004 for ticker KRC.
# 2026-06-07 15:44:44,274, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2004
# 2026-06-07 15:44:44,311, 2113979629.py, 8, INFO, Processing year 2005 for ticker KRC.
# 2026-06-07 15:44:44,321, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2005
# 2026-06-07 15:44:44,352, 2113979629.py, 8, INFO, Processing year 2006 for ticker KRC.
# 2026-06-07 15:44:44,362, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2006
# 2026-06-07 15:44:44,394, 2113979629.py, 8, INFO, Processing year 2007 for ticker KRC.
# 2026-06-07 15:44:44,402, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2007
# 2026-06-07 15:44:44,435, 2113979629.py, 8, INFO, Processing year 2008 for ticker KRC.
# 2026-06-07 15:44:44,446, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2008
# 2026-06-07 15:44:44,476, 2113979629.py, 8, INFO, Processing year 2009 for ticker KRC.
# 2026-06-07 15:44:44,486, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2009
# 2026-06-07 15:44:44,513, 2113979629.py, 8, INFO, Processing year 2010 for ticker KRC.
# 2026-06-07 15:44:44,526, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2010
# 2026-06-07 15:44:44,565, 2113979629.py, 8, INFO, Processing year 2011 for ticker KRC.
# 2026-06-07 15:44:44,574, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2011
# 2026-06-07 15:44:44,612, 2113979629.py, 8, INFO, Processing year 2012 for ticker KRC.
# 2026-06-07 15:44:44,622, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2012
# 2026-06-07 15:44:44,653, 2113979629.py, 8, INFO, Processing year 2013 for ticker KRC.
# 2026-06-07 15:44:44,663, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2013
# 2026-06-07 15:44:44,699, 2113979629.py, 8, INFO, Processing year 2014 for ticker KRC.
# 2026-06-07 15:44:44,708, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2014
# 2026-06-07 15:44:44,742, 2113979629.py, 8, INFO, Processing year 2015 for ticker KRC.
# 2026-06-07 15:44:44,752, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2015
# 2026-06-07 15:44:44,787, 2113979629.py, 8, INFO, Processing year 2016 for ticker KRC.
# 2026-06-07 15:44:44,797, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2016
# 2026-06-07 15:44:44,843, 2113979629.py, 8, INFO, Processing year 2017 for ticker KRC.
# 2026-06-07 15:44:44,854, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2017
# 2026-06-07 15:44:44,890, 2113979629.py, 8, INFO, Processing year 2018 for ticker KRC.
# 2026-06-07 15:44:44,897, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2018
# 2026-06-07 15:44:44,931, 2113979629.py, 8, INFO, Processing year 2019 for ticker KRC.
# 2026-06-07 15:44:44,939, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2019
# 2026-06-07 15:44:44,970, 2113979629.py, 8, INFO, Processing year 2020 for ticker KRC.
# 2026-06-07 15:44:44,979, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2020
# 2026-06-07 15:44:45,010, 2113979629.py, 4, INFO, Processing ticker: MICT
# 2026-06-07 15:44:45,035, 2113979629.py, 8, INFO, Processing year 2012 for ticker MICT.
# 2026-06-07 15:44:45,045, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MICT/MICT_2012
# 2026-06-07 15:44:45,109, 2113979629.py, 8, INFO, Processing year 2013 for ticker MICT.
# 2026-06-07 15:44:45,118, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MICT/MICT_2013
# 2026-06-07 15:44:45,155, 2113979629.py, 8, INFO, Processing year 2014 for ticker MICT.
# 2026-06-07 15:44:45,164, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MICT/MICT_2014
# 2026-06-07 15:44:45,201, 2113979629.py, 8, INFO, Processing year 2015 for ticker MICT.
# 2026-06-07 15:44:45,211, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MICT/MICT_2015
# 2026-06-07 15:44:45,244, 2113979629.py, 8, INFO, Processing year 2016 for ticker MICT.
# 2026-06-07 15:44:45,253, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MICT/MICT_2016
# 2026-06-07 15:44:45,284, 2113979629.py, 8, INFO, Processing year 2017 for ticker MICT.
# 2026-06-07 15:44:45,292, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MICT/MICT_2017
# 2026-06-07 15:44:45,329, 2113979629.py, 8, INFO, Processing year 2018 for ticker MICT.
# 2026-06-07 15:44:45,341, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MICT/MICT_2018
# 2026-06-07 15:44:45,380, 2113979629.py, 8, INFO, Processing year 2019 for ticker MICT.
# 2026-06-07 15:44:45,391, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MICT/MICT_2019
# 2026-06-07 15:44:45,424, 2113979629.py, 8, INFO, Processing year 2020 for ticker MICT.
# 2026-06-07 15:44:45,435, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MICT/MICT_2020
# 2026-06-07 15:44:45,464, 2113979629.py, 4, INFO, Processing ticker: AMPY
# 2026-06-07 15:44:45,485, 2113979629.py, 8, INFO, Processing year 2012 for ticker AMPY.
# 2026-06-07 15:44:45,492, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMPY/AMPY_2012
# 2026-06-07 15:44:45,520, 2113979629.py, 8, INFO, Processing year 2013 for ticker AMPY.
# 2026-06-07 15:44:45,527, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMPY/AMPY_2013
# 2026-06-07 15:44:45,567, 2113979629.py, 8, INFO, Processing year 2014 for ticker AMPY.
# 2026-06-07 15:44:45,581, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMPY/AMPY_2014
# 2026-06-07 15:44:45,621, 2113979629.py, 8, INFO, Processing year 2015 for ticker AMPY.
# 2026-06-07 15:44:45,635, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMPY/AMPY_2015
# 2026-06-07 15:44:45,669, 2113979629.py, 8, INFO, Processing year 2016 for ticker AMPY.
# 2026-06-07 15:44:45,678, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMPY/AMPY_2016
# 2026-06-07 15:44:45,714, 2113979629.py, 8, INFO, Processing year 2017 for ticker AMPY.
# 2026-06-07 15:44:45,725, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMPY/AMPY_2017
# 2026-06-07 15:44:45,765, 2113979629.py, 8, INFO, Processing year 2018 for ticker AMPY.
# 2026-06-07 15:44:45,774, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMPY/AMPY_2018
# 2026-06-07 15:44:45,807, 2113979629.py, 8, INFO, Processing year 2019 for ticker AMPY.
# 2026-06-07 15:44:45,816, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMPY/AMPY_2019
# 2026-06-07 15:44:45,856, 2113979629.py, 8, INFO, Processing year 2020 for ticker AMPY.
# 2026-06-07 15:44:45,864, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMPY/AMPY_2020
# 2026-06-07 15:44:45,901, 2113979629.py, 4, INFO, Processing ticker: A
# 2026-06-07 15:44:45,922, 2113979629.py, 8, INFO, Processing year 1999 for ticker A.
# 2026-06-07 15:44:45,933, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_1999
# 2026-06-07 15:44:45,968, 2113979629.py, 8, INFO, Processing year 2000 for ticker A.
# 2026-06-07 15:44:45,977, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2000
# 2026-06-07 15:44:46,014, 2113979629.py, 8, INFO, Processing year 2001 for ticker A.
# 2026-06-07 15:44:46,024, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2001
# 2026-06-07 15:44:46,067, 2113979629.py, 8, INFO, Processing year 2002 for ticker A.
# 2026-06-07 15:44:46,080, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2002
# 2026-06-07 15:44:46,117, 2113979629.py, 8, INFO, Processing year 2003 for ticker A.
# 2026-06-07 15:44:46,130, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2003
# 2026-06-07 15:44:46,169, 2113979629.py, 8, INFO, Processing year 2004 for ticker A.
# 2026-06-07 15:44:46,182, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2004
# 2026-06-07 15:44:46,221, 2113979629.py, 8, INFO, Processing year 2005 for ticker A.
# 2026-06-07 15:44:46,233, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2005
# 2026-06-07 15:44:46,267, 2113979629.py, 8, INFO, Processing year 2006 for ticker A.
# 2026-06-07 15:44:46,274, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2006
# 2026-06-07 15:44:46,305, 2113979629.py, 8, INFO, Processing year 2007 for ticker A.
# 2026-06-07 15:44:46,315, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2007
# 2026-06-07 15:44:46,369, 2113979629.py, 8, INFO, Processing year 2008 for ticker A.
# 2026-06-07 15:44:46,378, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2008
# 2026-06-07 15:44:46,417, 2113979629.py, 8, INFO, Processing year 2009 for ticker A.
# 2026-06-07 15:44:46,429, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2009
# 2026-06-07 15:44:46,467, 2113979629.py, 8, INFO, Processing year 2010 for ticker A.
# 2026-06-07 15:44:46,476, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2010
# 2026-06-07 15:44:46,508, 2113979629.py, 8, INFO, Processing year 2011 for ticker A.
# 2026-06-07 15:44:46,516, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2011
# 2026-06-07 15:44:46,551, 2113979629.py, 8, INFO, Processing year 2012 for ticker A.
# 2026-06-07 15:44:46,558, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2012
# 2026-06-07 15:44:46,594, 2113979629.py, 8, INFO, Processing year 2013 for ticker A.
# 2026-06-07 15:44:46,604, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2013
# 2026-06-07 15:44:46,640, 2113979629.py, 8, INFO, Processing year 2014 for ticker A.
# 2026-06-07 15:44:46,650, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2014
# 2026-06-07 15:44:46,687, 2113979629.py, 8, INFO, Processing year 2015 for ticker A.
# 2026-06-07 15:44:46,696, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2015
# 2026-06-07 15:44:46,726, 2113979629.py, 8, INFO, Processing year 2016 for ticker A.
# 2026-06-07 15:44:46,735, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2016
# 2026-06-07 15:44:46,764, 2113979629.py, 8, INFO, Processing year 2017 for ticker A.
# 2026-06-07 15:44:46,772, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2017
# 2026-06-07 15:44:46,803, 2113979629.py, 8, INFO, Processing year 2018 for ticker A.
# 2026-06-07 15:44:46,811, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2018
# 2026-06-07 15:44:46,849, 2113979629.py, 8, INFO, Processing year 2019 for ticker A.
# 2026-06-07 15:44:46,861, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2019
# 2026-06-07 15:44:46,906, 2113979629.py, 8, INFO, Processing year 2020 for ticker A.
# 2026-06-07 15:44:46,916, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2020
# 2026-06-07 15:44:46,951, 2113979629.py, 4, INFO, Processing ticker: WRLSU
# 2026-06-07 15:44:46,972, 2113979629.py, 8, INFO, Processing year 2017 for ticker WRLSU.
# 2026-06-07 15:44:46,981, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/WRLSU/WRLSU_2017
# 2026-06-07 15:44:47,016, 2113979629.py, 8, INFO, Processing year 2018 for ticker WRLSU.
# 2026-06-07 15:44:47,025, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/WRLSU/WRLSU_2018
# 2026-06-07 15:44:47,066, 2113979629.py, 8, INFO, Processing year 2019 for ticker WRLSU.
# 2026-06-07 15:44:47,080, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/WRLSU/WRLSU_2019
# 2026-06-07 15:44:47,125, 2113979629.py, 8, INFO, Processing year 2020 for ticker WRLSU.
# 2026-06-07 15:44:47,140, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/WRLSU/WRLSU_2020
# 2026-06-07 15:44:47,174, 2113979629.py, 4, INFO, Processing ticker: PNR
# 2026-06-07 15:44:47,203, 2113979629.py, 8, INFO, Processing year 1973 for ticker PNR.
# 2026-06-07 15:44:47,211, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1973
# 2026-06-07 15:44:47,253, 2113979629.py, 8, INFO, Processing year 1974 for ticker PNR.
# 2026-06-07 15:44:47,263, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1974
# 2026-06-07 15:44:47,310, 2113979629.py, 8, INFO, Processing year 1975 for ticker PNR.
# 2026-06-07 15:44:47,321, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1975
# 2026-06-07 15:44:47,374, 2113979629.py, 8, INFO, Processing year 1976 for ticker PNR.
# 2026-06-07 15:44:47,390, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1976
# 2026-06-07 15:44:47,426, 2113979629.py, 8, INFO, Processing year 1977 for ticker PNR.
# 2026-06-07 15:44:47,439, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1977
# 2026-06-07 15:44:47,474, 2113979629.py, 8, INFO, Processing year 1978 for ticker PNR.
# 2026-06-07 15:44:47,486, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1978
# 2026-06-07 15:44:47,522, 2113979629.py, 8, INFO, Processing year 1979 for ticker PNR.
# 2026-06-07 15:44:47,534, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1979
# 2026-06-07 15:44:47,578, 2113979629.py, 8, INFO, Processing year 1980 for ticker PNR.
# 2026-06-07 15:44:47,593, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1980
# 2026-06-07 15:44:47,650, 2113979629.py, 8, INFO, Processing year 1981 for ticker PNR.
# 2026-06-07 15:44:47,661, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1981
# 2026-06-07 15:44:47,700, 2113979629.py, 8, INFO, Processing year 1982 for ticker PNR.
# 2026-06-07 15:44:47,707, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1982
# 2026-06-07 15:44:47,743, 2113979629.py, 8, INFO, Processing year 1983 for ticker PNR.
# 2026-06-07 15:44:47,750, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1983
# 2026-06-07 15:44:47,790, 2113979629.py, 8, INFO, Processing year 1984 for ticker PNR.
# 2026-06-07 15:44:47,797, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1984
# 2026-06-07 15:44:47,834, 2113979629.py, 8, INFO, Processing year 1985 for ticker PNR.
# 2026-06-07 15:44:47,842, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1985
# 2026-06-07 15:44:47,883, 2113979629.py, 8, INFO, Processing year 1986 for ticker PNR.
# 2026-06-07 15:44:47,895, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1986
# 2026-06-07 15:44:47,937, 2113979629.py, 8, INFO, Processing year 1987 for ticker PNR.
# 2026-06-07 15:44:47,947, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1987
# 2026-06-07 15:44:47,989, 2113979629.py, 8, INFO, Processing year 1988 for ticker PNR.
# 2026-06-07 15:44:47,999, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1988
# 2026-06-07 15:44:48,037, 2113979629.py, 8, INFO, Processing year 1989 for ticker PNR.
# 2026-06-07 15:44:48,047, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1989
# 2026-06-07 15:44:48,082, 2113979629.py, 8, INFO, Processing year 1990 for ticker PNR.
# 2026-06-07 15:44:48,091, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1990
# 2026-06-07 15:44:48,126, 2113979629.py, 8, INFO, Processing year 1991 for ticker PNR.
# 2026-06-07 15:44:48,136, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1991
# 2026-06-07 15:44:48,173, 2113979629.py, 8, INFO, Processing year 1992 for ticker PNR.
# 2026-06-07 15:44:48,185, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1992
# 2026-06-07 15:44:48,226, 2113979629.py, 8, INFO, Processing year 1993 for ticker PNR.
# 2026-06-07 15:44:48,240, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1993
# 2026-06-07 15:44:48,283, 2113979629.py, 8, INFO, Processing year 1994 for ticker PNR.
# 2026-06-07 15:44:48,294, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1994
# 2026-06-07 15:44:48,325, 2113979629.py, 8, INFO, Processing year 1995 for ticker PNR.
# 2026-06-07 15:44:48,339, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1995
# 2026-06-07 15:44:48,458, 2113979629.py, 8, INFO, Processing year 1996 for ticker PNR.
# 2026-06-07 15:44:48,474, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1996
# 2026-06-07 15:44:48,511, 2113979629.py, 8, INFO, Processing year 1997 for ticker PNR.
# 2026-06-07 15:44:48,520, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1997
# 2026-06-07 15:44:48,656, 2113979629.py, 8, INFO, Processing year 1998 for ticker PNR.
# 2026-06-07 15:44:48,684, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1998
# 2026-06-07 15:44:48,719, 2113979629.py, 8, INFO, Processing year 1999 for ticker PNR.
# 2026-06-07 15:44:48,729, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1999
# 2026-06-07 15:44:48,768, 2113979629.py, 8, INFO, Processing year 2000 for ticker PNR.
# 2026-06-07 15:44:48,776, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_2000
# 2026-06-07 15:44:48,812, 2113979629.py, 8, INFO, Processing year 2001 for ticker PNR.
# 2026-06-07 15:44:48,819, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_2001
# 2026-06-07 15:44:48,849, 2113979629.py, 8, INFO, Processing year 2002 for ticker PNR.
# 2026-06-07 15:44:48,856, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_2002
# 2026-06-07 15:44:48,889, 2113979629.py, 8, INFO, Processing year 2003 for ticker PNR.
# 2026-06-07 15:44:48,898, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_2003
# 2026-06-07 15:44:48,930, 2113979629.py, 8, INFO, Processing year 2004 for ticker PNR.
# 2026-06-07 15:44:48,941, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_2004
# 2026-06-07 15:44:48,970, 2113979629.py, 8, INFO, Processing year 2005 for ticker PNR.
# 2026-06-07 15:44:48,981, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_2005
# 2026-06-07 15:44:49,015, 2113979629.py, 8, INFO, Processing year 2006 for ticker PNR.
# 2026-06-07 15:44:49,024, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_2006
# ...
# 2026-06-07 15:45:26,895, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2000
# 2026-06-07 15:45:26,925, 2113979629.py, 8, INFO, Processing year 2001 for ticker AMAT.
# 2026-06-07 15:45:26,937, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2001
# 2026-06-07 15:45:26,972, 2113979629.py, 8, INFO, Processing year 2002 for ticker AMAT.
# 2026-06-07 15:45:26,986, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2002
# 2026-06-07 15:45:27,027, 2113979629.py, 8, INFO, Processing year 2003 for ticker AMAT.
# 2026-06-07 15:45:27,040, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2003
# 2026-06-07 15:45:27,086, 2113979629.py, 8, INFO, Processing year 2004 for ticker AMAT.
# 2026-06-07 15:45:27,097, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2004
# 2026-06-07 15:45:27,142, 2113979629.py, 8, INFO, Processing year 2005 for ticker AMAT.
# 2026-06-07 15:45:27,152, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2005
# 2026-06-07 15:45:27,191, 2113979629.py, 8, INFO, Processing year 2006 for ticker AMAT.
# 2026-06-07 15:45:27,200, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2006
# 2026-06-07 15:45:27,240, 2113979629.py, 8, INFO, Processing year 2007 for ticker AMAT.
# 2026-06-07 15:45:27,250, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2007
# 2026-06-07 15:45:27,291, 2113979629.py, 8, INFO, Processing year 2008 for ticker AMAT.
# 2026-06-07 15:45:27,301, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2008
# 2026-06-07 15:45:27,361, 2113979629.py, 8, INFO, Processing year 2009 for ticker AMAT.
# 2026-06-07 15:45:27,371, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2009
# 2026-06-07 15:45:27,407, 2113979629.py, 8, INFO, Processing year 2010 for ticker AMAT.
# 2026-06-07 15:45:27,417, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2010
# 2026-06-07 15:45:27,460, 2113979629.py, 8, INFO, Processing year 2011 for ticker AMAT.
# 2026-06-07 15:45:27,471, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2011
# 2026-06-07 15:45:27,510, 2113979629.py, 8, INFO, Processing year 2012 for ticker AMAT.
# 2026-06-07 15:45:27,520, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2012
# 2026-06-07 15:45:27,560, 2113979629.py, 8, INFO, Processing year 2013 for ticker AMAT.
# 2026-06-07 15:45:27,571, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2013
# 2026-06-07 15:45:27,615, 2113979629.py, 8, INFO, Processing year 2014 for ticker AMAT.
# 2026-06-07 15:45:27,624, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2014
# 2026-06-07 15:45:27,662, 2113979629.py, 8, INFO, Processing year 2015 for ticker AMAT.
# 2026-06-07 15:45:27,675, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2015
# 2026-06-07 15:45:27,713, 2113979629.py, 8, INFO, Processing year 2016 for ticker AMAT.
# 2026-06-07 15:45:27,721, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2016
# 2026-06-07 15:45:27,760, 2113979629.py, 8, INFO, Processing year 2017 for ticker AMAT.
# 2026-06-07 15:45:27,770, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2017
# 2026-06-07 15:45:27,843, 2113979629.py, 8, INFO, Processing year 2018 for ticker AMAT.
# 2026-06-07 15:45:27,856, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2018
# 2026-06-07 15:45:27,905, 2113979629.py, 8, INFO, Processing year 2019 for ticker AMAT.
# 2026-06-07 15:45:27,916, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2019
# 2026-06-07 15:45:27,955, 2113979629.py, 8, INFO, Processing year 2020 for ticker AMAT.
# 2026-06-07 15:45:27,964, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2020
# 2026-06-07 15:45:27,997, 2113979629.py, 4, INFO, Processing ticker: PSB
# 2026-06-07 15:45:28,023, 2113979629.py, 8, INFO, Processing year 1991 for ticker PSB.
# 2026-06-07 15:45:28,036, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_1991
# 2026-06-07 15:45:28,078, 2113979629.py, 8, INFO, Processing year 1992 for ticker PSB.
# 2026-06-07 15:45:28,090, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_1992
# 2026-06-07 15:45:28,123, 2113979629.py, 8, INFO, Processing year 1993 for ticker PSB.
# 2026-06-07 15:45:28,137, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_1993
# 2026-06-07 15:45:28,173, 2113979629.py, 8, INFO, Processing year 1994 for ticker PSB.
# 2026-06-07 15:45:28,184, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_1994
# 2026-06-07 15:45:28,224, 2113979629.py, 8, INFO, Processing year 1995 for ticker PSB.
# 2026-06-07 15:45:28,236, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_1995
# 2026-06-07 15:45:28,279, 2113979629.py, 8, INFO, Processing year 1996 for ticker PSB.
# 2026-06-07 15:45:28,293, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_1996
# 2026-06-07 15:45:28,332, 2113979629.py, 8, INFO, Processing year 1997 for ticker PSB.
# 2026-06-07 15:45:28,344, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_1997
# 2026-06-07 15:45:28,385, 2113979629.py, 8, INFO, Processing year 1998 for ticker PSB.
# 2026-06-07 15:45:28,395, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_1998
# 2026-06-07 15:45:28,432, 2113979629.py, 8, INFO, Processing year 1999 for ticker PSB.
# 2026-06-07 15:45:28,445, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_1999
# 2026-06-07 15:45:28,515, 2113979629.py, 8, INFO, Processing year 2000 for ticker PSB.
# 2026-06-07 15:45:28,527, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2000
# 2026-06-07 15:45:28,577, 2113979629.py, 8, INFO, Processing year 2001 for ticker PSB.
# 2026-06-07 15:45:28,588, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2001
# 2026-06-07 15:45:28,625, 2113979629.py, 8, INFO, Processing year 2002 for ticker PSB.
# 2026-06-07 15:45:28,635, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2002
# 2026-06-07 15:45:28,675, 2113979629.py, 8, INFO, Processing year 2003 for ticker PSB.
# 2026-06-07 15:45:28,684, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2003
# 2026-06-07 15:45:28,722, 2113979629.py, 8, INFO, Processing year 2004 for ticker PSB.
# 2026-06-07 15:45:28,734, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2004
# 2026-06-07 15:45:28,781, 2113979629.py, 8, INFO, Processing year 2005 for ticker PSB.
# 2026-06-07 15:45:28,793, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2005
# 2026-06-07 15:45:28,836, 2113979629.py, 8, INFO, Processing year 2006 for ticker PSB.
# 2026-06-07 15:45:28,844, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2006
# 2026-06-07 15:45:28,879, 2113979629.py, 8, INFO, Processing year 2007 for ticker PSB.
# 2026-06-07 15:45:28,890, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2007
# 2026-06-07 15:45:28,924, 2113979629.py, 8, INFO, Processing year 2008 for ticker PSB.
# 2026-06-07 15:45:28,938, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2008
# 2026-06-07 15:45:28,974, 2113979629.py, 8, INFO, Processing year 2009 for ticker PSB.
# 2026-06-07 15:45:28,986, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2009
# 2026-06-07 15:45:29,023, 2113979629.py, 8, INFO, Processing year 2010 for ticker PSB.
# 2026-06-07 15:45:29,036, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2010
# 2026-06-07 15:45:29,076, 2113979629.py, 8, INFO, Processing year 2011 for ticker PSB.
# 2026-06-07 15:45:29,089, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2011
# 2026-06-07 15:45:29,122, 2113979629.py, 8, INFO, Processing year 2012 for ticker PSB.
# 2026-06-07 15:45:29,133, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2012
# 2026-06-07 15:45:29,166, 2113979629.py, 8, INFO, Processing year 2013 for ticker PSB.
# 2026-06-07 15:45:29,176, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2013
# 2026-06-07 15:45:29,246, 2113979629.py, 8, INFO, Processing year 2014 for ticker PSB.
# 2026-06-07 15:45:29,258, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2014
# 2026-06-07 15:45:29,325, 2113979629.py, 8, INFO, Processing year 2015 for ticker PSB.
# 2026-06-07 15:45:29,343, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2015
# 2026-06-07 15:45:29,396, 2113979629.py, 8, INFO, Processing year 2016 for ticker PSB.
# 2026-06-07 15:45:29,407, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2016
# 2026-06-07 15:45:29,454, 2113979629.py, 8, INFO, Processing year 2017 for ticker PSB.
# 2026-06-07 15:45:29,466, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2017
# 2026-06-07 15:45:29,513, 2113979629.py, 8, INFO, Processing year 2018 for ticker PSB.
# 2026-06-07 15:45:29,524, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2018
# 2026-06-07 15:45:29,575, 2113979629.py, 8, INFO, Processing year 2019 for ticker PSB.
# 2026-06-07 15:45:29,587, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2019
# 2026-06-07 15:45:29,625, 2113979629.py, 8, INFO, Processing year 2020 for ticker PSB.
# 2026-06-07 15:45:29,640, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2020
# 2026-06-07 15:45:29,682, 2113979629.py, 4, INFO, Processing ticker: CTSO
# 2026-06-07 15:45:29,712, 2113979629.py, 8, INFO, Processing year 2006 for ticker CTSO.
# 2026-06-07 15:45:29,724, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CTSO/CTSO_2006
# 2026-06-07 15:45:29,784, 2113979629.py, 8, INFO, Processing year 2007 for ticker CTSO.
# 2026-06-07 15:45:29,796, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CTSO/CTSO_2007
# 2026-06-07 15:45:29,848, 2113979629.py, 8, INFO, Processing year 2008 for ticker CTSO.
# 2026-06-07 15:45:29,859, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CTSO/CTSO_2008
# 2026-06-07 15:45:29,908, 2113979629.py, 8, INFO, Processing year 2009 for ticker CTSO.
# 2026-06-07 15:45:29,920, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CTSO/CTSO_2009
# 2026-06-07 15:45:29,961, 2113979629.py, 8, INFO, Processing year 2010 for ticker CTSO.
# 2026-06-07 15:45:29,974, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CTSO/CTSO_2010
# 2026-06-07 15:45:30,017, 2113979629.py, 8, INFO, Processing year 2011 for ticker CTSO.
# 2026-06-07 15:45:30,031, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CTSO/CTSO_2011
# 2026-06-07 15:45:30,074, 2113979629.py, 8, INFO, Processing year 2012 for ticker CTSO.
# 2026-06-07 15:45:30,090, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CTSO/CTSO_2012
# 2026-06-07 15:45:30,140, 2113979629.py, 8, INFO, Processing year 2013 for ticker CTSO.
# 2026-06-07 15:45:30,151, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CTSO/CTSO_2013
# 2026-06-07 15:45:30,198, 2113979629.py, 8, INFO, Processing year 2014 for ticker CTSO.
# 2026-06-07 15:45:30,207, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CTSO/CTSO_2014
# 2026-06-07 15:45:30,259, 2113979629.py, 8, INFO, Processing year 2015 for ticker CTSO.
# 2026-06-07 15:45:30,271, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CTSO/CTSO_2015
# 2026-06-07 15:45:30,316, 2113979629.py, 8, INFO, Processing year 2016 for ticker CTSO.
# 2026-06-07 15:45:30,328, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CTSO/CTSO_2016
# 2026-06-07 15:45:30,384, 2113979629.py, 8, INFO, Processing year 2017 for ticker CTSO.
# 2026-06-07 15:45:30,397, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CTSO/CTSO_2017
# 2026-06-07 15:45:30,443, 2113979629.py, 8, INFO, Processing year 2018 for ticker CTSO.
# 2026-06-07 15:45:30,453, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CTSO/CTSO_2018
# 2026-06-07 15:45:30,602, 2113979629.py, 8, INFO, Processing year 2019 for ticker CTSO.
# 2026-06-07 15:45:30,621, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CTSO/CTSO_2019
# 2026-06-07 15:45:30,724, 2113979629.py, 8, INFO, Processing year 2020 for ticker CTSO.
# 2026-06-07 15:45:30,741, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CTSO/CTSO_2020
# 2026-06-07 15:45:30,789, 2113979629.py, 4, INFO, Processing ticker: UEC
# 2026-06-07 15:45:30,819, 2113979629.py, 8, INFO, Processing year 2007 for ticker UEC.
# 2026-06-07 15:45:30,830, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/UEC/UEC_2007
# 2026-06-07 15:45:30,873, 2113979629.py, 8, INFO, Processing year 2008 for ticker UEC.
# 2026-06-07 15:45:30,889, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/UEC/UEC_2008
# 2026-06-07 15:45:30,938, 2113979629.py, 8, INFO, Processing year 2009 for ticker UEC.
# 2026-06-07 15:45:30,950, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/UEC/UEC_2009
# 2026-06-07 15:45:30,991, 2113979629.py, 8, INFO, Processing year 2010 for ticker UEC.
# 2026-06-07 15:45:31,001, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/UEC/UEC_2010
# 2026-06-07 15:45:31,055, 2113979629.py, 8, INFO, Processing year 2011 for ticker UEC.
# 2026-06-07 15:45:31,067, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/UEC/UEC_2011
# 2026-06-07 15:45:31,114, 2113979629.py, 8, INFO, Processing year 2012 for ticker UEC.
# 2026-06-07 15:45:31,126, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/UEC/UEC_2012
# 2026-06-07 15:45:31,175, 2113979629.py, 8, INFO, Processing year 2013 for ticker UEC.
# 2026-06-07 15:45:31,189, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/UEC/UEC_2013
# 2026-06-07 15:45:31,232, 2113979629.py, 8, INFO, Processing year 2014 for ticker UEC.
# 2026-06-07 15:45:31,244, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/UEC/UEC_2014
# 2026-06-07 15:45:31,287, 2113979629.py, 8, INFO, Processing year 2015 for ticker UEC.
# 2026-06-07 15:45:31,298, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/UEC/UEC_2015
# 2026-06-07 15:45:31,338, 2113979629.py, 8, INFO, Processing year 2016 for ticker UEC.
# 2026-06-07 15:45:31,347, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/UEC/UEC_2016
# 2026-06-07 15:45:31,378, 2113979629.py, 8, INFO, Processing year 2017 for ticker UEC.
# 2026-06-07 15:45:31,386, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/UEC/UEC_2017
# 2026-06-07 15:45:31,419, 2113979629.py, 8, INFO, Processing year 2018 for ticker UEC.
# 2026-06-07 15:45:31,430, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/UEC/UEC_2018
# 2026-06-07 15:45:31,477, 2113979629.py, 8, INFO, Processing year 2019 for ticker UEC.
# 2026-06-07 15:45:31,491, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/UEC/UEC_2019
# 2026-06-07 15:45:31,535, 2113979629.py, 8, INFO, Processing year 2020 for ticker UEC.
# 2026-06-07 15:45:31,545, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/UEC/UEC_2020

# %% [markdown]
# Why would we want to store data this way?
#
# + Data files are easier to maintain. We do not update old data, only recent data or the most recent "delta".
# + Parquet files, as long as they maintain a consistent schema, can all be read jointly.

# %% [markdown]
# # Load, Transform, and Save
#
# In this section, we will load the Parquet files we generated, transform the data, and save the resulting dataset.

# %% [markdown]
# ## Load
#
# + Parquet files can be read individually or as a collection.
# + `dd.read_parquet()` can take a list (collection) of files as input.
# + Use `glob` to obtain the collection of files.

# %%
from glob import glob

parquet_files = glob(os.path.join(PRICE_DATA, "**/*.parquet"), recursive = True)
_logs.info(f'Found {len(parquet_files)} parquet files for reading back into Dask.')

dd_px = dd.read_parquet(parquet_files).set_index("ticker")
# Out:
# 2026-06-07 15:45:38,323, 174194153.py, 4, INFO, Found 2010 parquet files for reading back into Dask.

# %% [markdown]
# ## Transform
#
# + This transformation step will create a *Features* data set. In our case, features will be stock returns (we obtained prices).
# + Dask dataframes work similarly to Pandas dataframes: in particular, we can perform groupby and apply operations.
# + Notice the use of [an anonymous (lambda) function](https://realpython.com/python-lambda/) in the apply statement.
#
# In the code below, the following operation occurs:
#
# + Start with a Dask dataframe, `dd_px`.
# + Group the rows of this dataframe by the variable `ticker`, i.e., each group will contain the observations that pertain only to one ticker at a time. The `group_key` parameter controls whether an index entry is added with the value of the grouping variable (`ticker` in this case); if we made `group_keys=True`, we would have a duplicate `ticker` column.
# + For each group defined by a `ticker`, `apply()` the following calculation:
#
#     - Sort the values by `Date` in ascending order.
#     - Assign a new variable called `Close_lag_1` by shifting the position of the closing price (`Close`) by one position.
#     - Define the schema of the resulting dataframe. If we omit this specification, we would get a warning; however, the simplicity of the calculation ensures that Dask can determine the resulting schema.

# %%
dd_px
# Out:
# Dask DataFrame Structure:
#                           Date     Open     High      Low    Close Adj Close   Volume  source   Year
# npartitions=60
# A               datetime64[ns]  float64  float64  float64  float64   float64  float64  string  int32
# ACB                        ...      ...      ...      ...      ...       ...      ...     ...    ...
# ...                        ...      ...      ...      ...      ...       ...      ...     ...    ...
# ZEUS                       ...      ...      ...      ...      ...       ...      ...     ...    ...
# ZEUS                       ...      ...      ...      ...      ...       ...      ...     ...    ...
# Dask Name: setindex, 2 expressions
# Expr=SetIndex(frame=ReadParquetFSSpec(4f66601), _other='ticker', options={})

# %%
dd_shift = (
    dd_px
        .groupby('ticker', group_keys=False)
        .apply(
            lambda x: x.sort_values('Date', ascending = True)
                       .assign(Close_lag_1 = x['Close'].shift(1)), 
            meta = pd.DataFrame(data ={'Date': 'datetime64[ns]',
                    'Open': 'f8',
                    'High': 'f8',
                    'Low': 'f8',
                    'Close': 'f8',
                    'Adj Close': 'f8',
                    'Volume': 'i8',
                    'source': 'object',
                    'Year': 'int32',
                    'Close_lag_1': 'f8'},
                    index = pd.Index([], dtype=pd.StringDtype(), name='ticker'))
    ))

# %% [markdown]
# Finally, using the dataframe that we created above, we can now `assign` the `Returns` variable to the entire dataset.

# %%
dd_rets = dd_shift.assign(
    Returns = lambda x: x['Close']/x['Close_lag_1'] - 1
)

# %% [markdown]
# Question: How do we know that we are not (erroneously) combining the last price of a ticker with the first price of the next ticker?

# %% [markdown]
# ## Lazy Execution
#
# What does `dd_rets` contain?

# %%
dd_rets
# Out:
# Dask DataFrame Structure:
#                   Date    Open    High     Low   Close Adj Close  Volume  source    Year Close_lag_1 Returns
# npartitions=60
# A               object  object  object  object  object    object  object  object  object      object  object
# ACB                ...     ...     ...     ...     ...       ...     ...     ...     ...         ...     ...
# ...                ...     ...     ...     ...     ...       ...     ...     ...     ...         ...     ...
# ZEUS               ...     ...     ...     ...     ...       ...     ...     ...     ...         ...     ...
# ZEUS               ...     ...     ...     ...     ...       ...     ...     ...     ...         ...     ...
# Dask Name: assign, 9 expressions
# Expr=Assign(frame=Assign(frame=GroupByApply(frame=SetIndex(frame=ReadParquetFSSpec(4f66601), _other='ticker', options={}), observed=False, group_keys=False, func=<function <lambda> at 0x15710a2a0>, args=(), kwargs={})))

# %% [markdown]
# + Dask is a lazy execution framework: commands will not execute until the computation is required.
# + To trigger an execution in dask use `.compute()` or execute a command that requires the actual values (for example, write to Parquet or SQL).

# %%
dd_rets.compute()
# Out:
#              Date       Open       High        Low      Close  Adj Close  \
# ticker
# A      1999-11-18  32.546494  35.765381  28.612303  31.473534  27.068665
# A      1999-11-19  30.713520  30.758226  28.478184  28.880543  24.838577
# A      1999-11-22  29.551144  31.473534  28.657009  31.473534  27.068665
# A      1999-11-23  30.400572  31.205294  28.612303  28.612303  24.607880
# A      1999-11-24  28.701717  29.998211  28.612303  29.372318  25.261524
# ...           ...        ...        ...        ...        ...        ...
# ZEUS   2020-03-26   9.610000   9.940000   9.260000   9.590000   9.590000
# ZEUS   2020-03-27   9.330000   9.330000   8.700000   8.700000   8.700000
# ZEUS   2020-03-30   8.810000   9.760000   8.700000   9.680000   9.680000
# ZEUS   2020-03-31   9.640000  10.470000   9.590000  10.350000  10.350000
# ZEUS   2020-04-01  10.140000  10.340000   9.310000   9.470000   9.470000
#
#             Volume    source  Year  Close_lag_1   Returns
# ticker
# A       62546300.0     A.csv  1999          NaN       NaN
# A       15234100.0     A.csv  1999    31.473534 -0.082386
# A        6577800.0     A.csv  1999    28.880543  0.089783
# A        5975600.0     A.csv  1999    31.473534 -0.090909
# A        4843200.0     A.csv  1999    28.612303  0.026563
# ...            ...       ...   ...          ...       ...
# ZEUS       60500.0  ZEUS.csv  2020     9.670000 -0.008273
# ZEUS       52900.0  ZEUS.csv  2020     9.590000 -0.092805
# ZEUS       73700.0  ZEUS.csv  2020     8.700000  0.112644
# ZEUS       68900.0  ZEUS.csv  2020     9.680000  0.069215
# ZEUS       34000.0  ZEUS.csv  2020    10.350000 -0.085024
#
# [230273 rows x 11 columns]

# %%
df = dd_rets.compute()
df.to_csv("test.csv")

# %%
df.head()
# Out:
#              Date       Open       High        Low      Close  Adj Close  \
# ticker
# A      1999-11-18  32.546494  35.765381  28.612303  31.473534  27.068665
# A      1999-11-19  30.713520  30.758226  28.478184  28.880543  24.838577
# A      1999-11-22  29.551144  31.473534  28.657009  31.473534  27.068665
# A      1999-11-23  30.400572  31.205294  28.612303  28.612303  24.607880
# A      1999-11-24  28.701717  29.998211  28.612303  29.372318  25.261524
#
#             Volume source  Year  Close_lag_1   Returns
# ticker
# A       62546300.0  A.csv  1999          NaN       NaN
# A       15234100.0  A.csv  1999    31.473534 -0.082386
# A        6577800.0  A.csv  1999    28.880543  0.089783
# A        5975600.0  A.csv  1999    31.473534 -0.090909
# A        4843200.0  A.csv  1999    28.612303  0.026563

# %% [markdown]
# ## Save
#
# With our transformed data, we can now save the new feature to a Parquet file. We will need to answer the following questions depending on our context, setup, and available resources:
#
# + Should we keep the same namespace?
# + Should we save all columns?

# %%
dd_rets
# Out:
# Dask DataFrame Structure:
#                   Date    Open    High     Low   Close Adj Close  Volume  source    Year Close_lag_1 Returns
# npartitions=60
# A               object  object  object  object  object    object  object  object  object      object  object
# ACB                ...     ...     ...     ...     ...       ...     ...     ...     ...         ...     ...
# ...                ...     ...     ...     ...     ...       ...     ...     ...     ...         ...     ...
# ZEUS               ...     ...     ...     ...     ...       ...     ...     ...     ...         ...     ...
# ZEUS               ...     ...     ...     ...     ...       ...     ...     ...     ...         ...     ...
# Dask Name: assign, 9 expressions
# Expr=Assign(frame=Assign(frame=GroupByApply(frame=SetIndex(frame=ReadParquetFSSpec(4f66601), _other='ticker', options={}), observed=False, group_keys=False, func=<function <lambda> at 0x15710a2a0>, args=(), kwargs={})))

# %%
# Clean up before save
FEATURES_DATA = os.getenv("FEATURES_DATA")
if os.path.exists(FEATURES_DATA):
    shutil.rmtree(FEATURES_DATA)
dd_rets.to_parquet(FEATURES_DATA, 
                   overwrite = True, 
                   schema={
                       'Date': 'timestamp[ns]',
                       'Open': 'float64',
                       'High': 'float64',
                       'Low': 'float64',
                       'Close': 'float64',
                       'Adj Close': 'float64',
                       'Volume': 'int64',
                       'source': 'string',
                       'Year': 'int32',
                       'Close_lag_1': 'float64',
                       'Returns': 'float64',
                       'ticker': 'large_string'
                   })

# %% [markdown]
# # Optional: from Jupyter to Command Line
#
# + We have drafted our code in a Jupyter Notebook.
# + Finalized code should be written in Python modules.
#
# ## Object Oriented vs Functional Programming
#
# + We can use classes to keep parameters and functions together.
# + We *could* use Object Oriented Programming, but parallelization of data manipulation and modelling tasks benefit from *Functional Programming*.
# + An Idea:
#
#     - [Data Oriented Programming](https://blog.klipse.tech/dop/2022/06/22/principles-of-dop.html).
#     - Use the class to bundle together parameters and functions.
#     - Use stateless operations and treat all data objects as immutable (we do not modify them, we overwrite them).
#     - Take advantage of [`@staticmethod`](https://realpython.com/instance-class-and-static-methods-demystified/).
#
# The code is in `../../05_src/stock_prices/data_manager.py`.

# %% [markdown]
# Our original design was:
#
# ![](./images/02_target_pipeline_manager.png)

# %%
from stock_prices.data_manager import DataManager
dm = DataManager()

# %% [markdown]
# Download all prices.

# %%
dm.process_sample_files()
# Out:
# 2026-06-07 15:47:31,750, data_manager.py, 110, INFO, Processing sample of tickers
# 2026-06-07 15:47:31,752, data_manager.py, 117, INFO, Getting file list from ../../05_src/data/prices_csv/
# 2026-06-07 15:47:31,808, data_manager.py, 119, INFO, Found 5884 files in ../../05_src/data/prices_csv/
# 2026-06-07 15:47:31,809, data_manager.py, 126, INFO, Selecting sample of files
# 2026-06-07 15:47:31,813, data_manager.py, 132, INFO, Selected 30 files
# 2026-06-07 15:47:31,822, data_manager.py, 137, INFO, Processing file ../../05_src/data/prices_csv/stocks/SFBS.csv
# 2026-06-07 15:47:31,825, data_manager.py, 186, INFO, Reading file: ../../05_src/data/prices_csv/stocks/SFBS.csv
# 2026-06-07 15:47:31,839, data_manager.py, 155, INFO, Saving data by year
# 2026-06-07 15:47:31,841, data_manager.py, 157, INFO, Processing ticker: SFBS
# 2026-06-07 15:47:31,846, data_manager.py, 161, INFO, Processing year 2014 for ticker SFBS.
# 2026-06-07 15:47:31,859, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/SFBS/SFBS_2014
# 2026-06-07 15:47:31,899, data_manager.py, 161, INFO, Processing year 2015 for ticker SFBS.
# 2026-06-07 15:47:31,923, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/SFBS/SFBS_2015
# 2026-06-07 15:47:32,064, data_manager.py, 161, INFO, Processing year 2016 for ticker SFBS.
# 2026-06-07 15:47:32,071, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/SFBS/SFBS_2016
# 2026-06-07 15:47:32,097, data_manager.py, 161, INFO, Processing year 2017 for ticker SFBS.
# 2026-06-07 15:47:32,108, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/SFBS/SFBS_2017
# 2026-06-07 15:47:32,144, data_manager.py, 161, INFO, Processing year 2018 for ticker SFBS.
# 2026-06-07 15:47:32,154, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/SFBS/SFBS_2018
# 2026-06-07 15:47:32,191, data_manager.py, 161, INFO, Processing year 2019 for ticker SFBS.
# 2026-06-07 15:47:32,204, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/SFBS/SFBS_2019
# 2026-06-07 15:47:32,258, data_manager.py, 161, INFO, Processing year 2020 for ticker SFBS.
# 2026-06-07 15:47:32,281, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/SFBS/SFBS_2020
# 2026-06-07 15:47:32,369, data_manager.py, 137, INFO, Processing file ../../05_src/data/prices_csv/stocks/MHF.csv
# 2026-06-07 15:47:32,371, data_manager.py, 186, INFO, Reading file: ../../05_src/data/prices_csv/stocks/MHF.csv
# 2026-06-07 15:47:32,458, data_manager.py, 155, INFO, Saving data by year
# 2026-06-07 15:47:32,462, data_manager.py, 157, INFO, Processing ticker: MHF
# 2026-06-07 15:47:32,474, data_manager.py, 161, INFO, Processing year 1988 for ticker MHF.
# 2026-06-07 15:47:32,504, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/MHF/MHF_1988
# 2026-06-07 15:47:32,594, data_manager.py, 161, INFO, Processing year 1989 for ticker MHF.
# 2026-06-07 15:47:32,615, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/MHF/MHF_1989
# 2026-06-07 15:47:32,716, data_manager.py, 161, INFO, Processing year 1990 for ticker MHF.
# 2026-06-07 15:47:32,764, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/MHF/MHF_1990
# 2026-06-07 15:47:32,876, data_manager.py, 161, INFO, Processing year 1991 for ticker MHF.
# 2026-06-07 15:47:32,901, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/MHF/MHF_1991
# 2026-06-07 15:47:32,981, data_manager.py, 161, INFO, Processing year 1992 for ticker MHF.
# 2026-06-07 15:47:33,008, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/MHF/MHF_1992
# 2026-06-07 15:47:33,083, data_manager.py, 161, INFO, Processing year 1993 for ticker MHF.
# 2026-06-07 15:47:33,101, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/MHF/MHF_1993
# 2026-06-07 15:47:33,217, data_manager.py, 161, INFO, Processing year 1994 for ticker MHF.
# 2026-06-07 15:47:33,236, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/MHF/MHF_1994
# 2026-06-07 15:47:33,299, data_manager.py, 161, INFO, Processing year 1995 for ticker MHF.
# 2026-06-07 15:47:33,321, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/MHF/MHF_1995
# 2026-06-07 15:47:33,441, data_manager.py, 161, INFO, Processing year 1996 for ticker MHF.
# 2026-06-07 15:47:33,459, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/MHF/MHF_1996
# 2026-06-07 15:47:33,541, data_manager.py, 161, INFO, Processing year 1997 for ticker MHF.
# 2026-06-07 15:47:33,563, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/MHF/MHF_1997
# 2026-06-07 15:47:33,631, data_manager.py, 161, INFO, Processing year 1998 for ticker MHF.
# 2026-06-07 15:47:33,653, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/MHF/MHF_1998
# 2026-06-07 15:47:33,740, data_manager.py, 161, INFO, Processing year 1999 for ticker MHF.
# 2026-06-07 15:47:33,754, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/MHF/MHF_1999
# 2026-06-07 15:47:33,826, data_manager.py, 161, INFO, Processing year 2000 for ticker MHF.
# 2026-06-07 15:47:33,846, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/MHF/MHF_2000
# 2026-06-07 15:47:33,904, data_manager.py, 161, INFO, Processing year 2001 for ticker MHF.
# 2026-06-07 15:47:33,929, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/MHF/MHF_2001
# 2026-06-07 15:47:33,998, data_manager.py, 161, INFO, Processing year 2002 for ticker MHF.
# 2026-06-07 15:47:34,012, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/MHF/MHF_2002
# 2026-06-07 15:47:34,096, data_manager.py, 161, INFO, Processing year 2003 for ticker MHF.
# 2026-06-07 15:47:34,111, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/MHF/MHF_2003
# 2026-06-07 15:47:34,211, data_manager.py, 161, INFO, Processing year 2004 for ticker MHF.
# 2026-06-07 15:47:34,237, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/MHF/MHF_2004
# 2026-06-07 15:47:34,376, data_manager.py, 161, INFO, Processing year 2005 for ticker MHF.
# 2026-06-07 15:47:34,393, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/MHF/MHF_2005
# 2026-06-07 15:47:34,457, data_manager.py, 161, INFO, Processing year 2006 for ticker MHF.
# 2026-06-07 15:47:34,468, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/MHF/MHF_2006
# 2026-06-07 15:47:34,519, data_manager.py, 161, INFO, Processing year 2007 for ticker MHF.
# 2026-06-07 15:47:34,536, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/MHF/MHF_2007
# 2026-06-07 15:47:34,593, data_manager.py, 161, INFO, Processing year 2008 for ticker MHF.
# 2026-06-07 15:47:34,604, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/MHF/MHF_2008
# 2026-06-07 15:47:34,644, data_manager.py, 161, INFO, Processing year 2009 for ticker MHF.
# 2026-06-07 15:47:34,654, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/MHF/MHF_2009
# 2026-06-07 15:47:34,692, data_manager.py, 161, INFO, Processing year 2010 for ticker MHF.
# 2026-06-07 15:47:34,701, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/MHF/MHF_2010
# 2026-06-07 15:47:34,742, data_manager.py, 161, INFO, Processing year 2011 for ticker MHF.
# 2026-06-07 15:47:34,753, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/MHF/MHF_2011
# 2026-06-07 15:47:34,801, data_manager.py, 161, INFO, Processing year 2012 for ticker MHF.
# 2026-06-07 15:47:34,813, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/MHF/MHF_2012
# 2026-06-07 15:47:34,870, data_manager.py, 161, INFO, Processing year 2013 for ticker MHF.
# 2026-06-07 15:47:34,885, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/MHF/MHF_2013
# 2026-06-07 15:47:34,937, data_manager.py, 161, INFO, Processing year 2014 for ticker MHF.
# 2026-06-07 15:47:34,947, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/MHF/MHF_2014
# 2026-06-07 15:47:34,996, data_manager.py, 161, INFO, Processing year 2015 for ticker MHF.
# 2026-06-07 15:47:35,006, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/MHF/MHF_2015
# 2026-06-07 15:47:35,049, data_manager.py, 161, INFO, Processing year 2016 for ticker MHF.
# 2026-06-07 15:47:35,059, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/MHF/MHF_2016
# 2026-06-07 15:47:35,108, data_manager.py, 161, INFO, Processing year 2017 for ticker MHF.
# 2026-06-07 15:47:35,120, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/MHF/MHF_2017
# 2026-06-07 15:47:35,170, data_manager.py, 161, INFO, Processing year 2018 for ticker MHF.
# 2026-06-07 15:47:35,183, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/MHF/MHF_2018
# 2026-06-07 15:47:35,228, data_manager.py, 161, INFO, Processing year 2019 for ticker MHF.
# 2026-06-07 15:47:35,239, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/MHF/MHF_2019
# 2026-06-07 15:47:35,283, data_manager.py, 161, INFO, Processing year 2020 for ticker MHF.
# 2026-06-07 15:47:35,291, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/MHF/MHF_2020
# 2026-06-07 15:47:35,337, data_manager.py, 137, INFO, Processing file ../../05_src/data/prices_csv/stocks/HL.csv
# 2026-06-07 15:47:35,338, data_manager.py, 186, INFO, Reading file: ../../05_src/data/prices_csv/stocks/HL.csv
# 2026-06-07 15:47:35,384, data_manager.py, 155, INFO, Saving data by year
# 2026-06-07 15:47:35,386, data_manager.py, 157, INFO, Processing ticker: HL
# 2026-06-07 15:47:35,394, data_manager.py, 161, INFO, Processing year 1980 for ticker HL.
# 2026-06-07 15:47:35,405, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HL/HL_1980
# 2026-06-07 15:47:35,455, data_manager.py, 161, INFO, Processing year 1981 for ticker HL.
# 2026-06-07 15:47:35,464, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HL/HL_1981
# 2026-06-07 15:47:35,528, data_manager.py, 161, INFO, Processing year 1982 for ticker HL.
# 2026-06-07 15:47:35,543, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HL/HL_1982
# 2026-06-07 15:47:35,609, data_manager.py, 161, INFO, Processing year 1983 for ticker HL.
# 2026-06-07 15:47:35,621, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HL/HL_1983
# 2026-06-07 15:47:35,684, data_manager.py, 161, INFO, Processing year 1984 for ticker HL.
# 2026-06-07 15:47:35,697, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HL/HL_1984
# 2026-06-07 15:47:35,757, data_manager.py, 161, INFO, Processing year 1985 for ticker HL.
# 2026-06-07 15:47:35,778, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HL/HL_1985
# 2026-06-07 15:47:35,857, data_manager.py, 161, INFO, Processing year 1986 for ticker HL.
# 2026-06-07 15:47:35,869, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HL/HL_1986
# 2026-06-07 15:47:35,930, data_manager.py, 161, INFO, Processing year 1987 for ticker HL.
# 2026-06-07 15:47:35,944, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HL/HL_1987
# 2026-06-07 15:47:36,047, data_manager.py, 161, INFO, Processing year 1988 for ticker HL.
# 2026-06-07 15:47:36,062, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HL/HL_1988
# 2026-06-07 15:47:36,118, data_manager.py, 161, INFO, Processing year 1989 for ticker HL.
# 2026-06-07 15:47:36,137, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HL/HL_1989
# 2026-06-07 15:47:36,203, data_manager.py, 161, INFO, Processing year 1990 for ticker HL.
# 2026-06-07 15:47:36,217, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HL/HL_1990
# 2026-06-07 15:47:36,281, data_manager.py, 161, INFO, Processing year 1991 for ticker HL.
# 2026-06-07 15:47:36,298, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HL/HL_1991
# 2026-06-07 15:47:36,359, data_manager.py, 161, INFO, Processing year 1992 for ticker HL.
# 2026-06-07 15:47:36,372, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HL/HL_1992
# 2026-06-07 15:47:36,439, data_manager.py, 161, INFO, Processing year 1993 for ticker HL.
# 2026-06-07 15:47:36,449, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HL/HL_1993
# 2026-06-07 15:47:36,490, data_manager.py, 161, INFO, Processing year 1994 for ticker HL.
# 2026-06-07 15:47:36,499, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HL/HL_1994
# 2026-06-07 15:47:36,535, data_manager.py, 161, INFO, Processing year 1995 for ticker HL.
# 2026-06-07 15:47:36,544, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HL/HL_1995
# 2026-06-07 15:47:36,589, data_manager.py, 161, INFO, Processing year 1996 for ticker HL.
# 2026-06-07 15:47:36,599, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HL/HL_1996
# 2026-06-07 15:47:36,649, data_manager.py, 161, INFO, Processing year 1997 for ticker HL.
# 2026-06-07 15:47:36,660, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HL/HL_1997
# 2026-06-07 15:47:36,731, data_manager.py, 161, INFO, Processing year 1998 for ticker HL.
# 2026-06-07 15:47:36,747, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HL/HL_1998
# 2026-06-07 15:47:36,799, data_manager.py, 161, INFO, Processing year 1999 for ticker HL.
# 2026-06-07 15:47:36,808, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HL/HL_1999
# 2026-06-07 15:47:36,852, data_manager.py, 161, INFO, Processing year 2000 for ticker HL.
# 2026-06-07 15:47:36,866, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HL/HL_2000
# 2026-06-07 15:47:36,931, data_manager.py, 161, INFO, Processing year 2001 for ticker HL.
# 2026-06-07 15:47:36,945, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HL/HL_2001
# 2026-06-07 15:47:36,997, data_manager.py, 161, INFO, Processing year 2002 for ticker HL.
# 2026-06-07 15:47:37,007, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HL/HL_2002
# 2026-06-07 15:47:37,048, data_manager.py, 161, INFO, Processing year 2003 for ticker HL.
# 2026-06-07 15:47:37,057, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HL/HL_2003
# 2026-06-07 15:47:37,100, data_manager.py, 161, INFO, Processing year 2004 for ticker HL.
# 2026-06-07 15:47:37,109, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HL/HL_2004
# 2026-06-07 15:47:37,146, data_manager.py, 161, INFO, Processing year 2005 for ticker HL.
# 2026-06-07 15:47:37,157, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HL/HL_2005
# 2026-06-07 15:47:37,198, data_manager.py, 161, INFO, Processing year 2006 for ticker HL.
# 2026-06-07 15:47:37,208, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HL/HL_2006
# 2026-06-07 15:47:37,248, data_manager.py, 161, INFO, Processing year 2007 for ticker HL.
# 2026-06-07 15:47:37,258, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HL/HL_2007
# 2026-06-07 15:47:37,307, data_manager.py, 161, INFO, Processing year 2008 for ticker HL.
# 2026-06-07 15:47:37,318, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HL/HL_2008
# 2026-06-07 15:47:37,377, data_manager.py, 161, INFO, Processing year 2009 for ticker HL.
# 2026-06-07 15:47:37,389, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HL/HL_2009
# 2026-06-07 15:47:37,450, data_manager.py, 161, INFO, Processing year 2010 for ticker HL.
# 2026-06-07 15:47:37,461, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HL/HL_2010
# 2026-06-07 15:47:37,500, data_manager.py, 161, INFO, Processing year 2011 for ticker HL.
# 2026-06-07 15:47:37,509, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HL/HL_2011
# 2026-06-07 15:47:37,543, data_manager.py, 161, INFO, Processing year 2012 for ticker HL.
# 2026-06-07 15:47:37,550, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HL/HL_2012
# 2026-06-07 15:47:37,590, data_manager.py, 161, INFO, Processing year 2013 for ticker HL.
# 2026-06-07 15:47:37,599, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HL/HL_2013
# 2026-06-07 15:47:37,637, data_manager.py, 161, INFO, Processing year 2014 for ticker HL.
# 2026-06-07 15:47:37,649, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HL/HL_2014
# 2026-06-07 15:47:37,696, data_manager.py, 161, INFO, Processing year 2015 for ticker HL.
# 2026-06-07 15:47:37,707, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HL/HL_2015
# 2026-06-07 15:47:37,750, data_manager.py, 161, INFO, Processing year 2016 for ticker HL.
# 2026-06-07 15:47:37,760, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HL/HL_2016
# 2026-06-07 15:47:37,800, data_manager.py, 161, INFO, Processing year 2017 for ticker HL.
# 2026-06-07 15:47:37,809, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HL/HL_2017
# 2026-06-07 15:47:37,846, data_manager.py, 161, INFO, Processing year 2018 for ticker HL.
# 2026-06-07 15:47:37,853, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HL/HL_2018
# 2026-06-07 15:47:37,893, data_manager.py, 161, INFO, Processing year 2019 for ticker HL.
# 2026-06-07 15:47:37,901, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HL/HL_2019
# 2026-06-07 15:47:37,954, data_manager.py, 161, INFO, Processing year 2020 for ticker HL.
# 2026-06-07 15:47:37,963, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HL/HL_2020
# 2026-06-07 15:47:38,005, data_manager.py, 137, INFO, Processing file ../../05_src/data/prices_csv/stocks/PML.csv
# 2026-06-07 15:47:38,006, data_manager.py, 186, INFO, Reading file: ../../05_src/data/prices_csv/stocks/PML.csv
# 2026-06-07 15:47:38,034, data_manager.py, 155, INFO, Saving data by year
# 2026-06-07 15:47:38,036, data_manager.py, 157, INFO, Processing ticker: PML
# 2026-06-07 15:47:38,044, data_manager.py, 161, INFO, Processing year 2002 for ticker PML.
# 2026-06-07 15:47:38,056, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/PML/PML_2002
# 2026-06-07 15:47:38,110, data_manager.py, 161, INFO, Processing year 2003 for ticker PML.
# 2026-06-07 15:47:38,119, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/PML/PML_2003
# 2026-06-07 15:47:38,160, data_manager.py, 161, INFO, Processing year 2004 for ticker PML.
# 2026-06-07 15:47:38,168, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/PML/PML_2004
# 2026-06-07 15:47:38,205, data_manager.py, 161, INFO, Processing year 2005 for ticker PML.
# 2026-06-07 15:47:38,218, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/PML/PML_2005
# 2026-06-07 15:47:38,289, data_manager.py, 161, INFO, Processing year 2006 for ticker PML.
# 2026-06-07 15:47:38,300, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/PML/PML_2006
# 2026-06-07 15:47:38,351, data_manager.py, 161, INFO, Processing year 2007 for ticker PML.
# 2026-06-07 15:47:38,361, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/PML/PML_2007
# 2026-06-07 15:47:38,400, data_manager.py, 161, INFO, Processing year 2008 for ticker PML.
# 2026-06-07 15:47:38,408, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/PML/PML_2008
# 2026-06-07 15:47:38,443, data_manager.py, 161, INFO, Processing year 2009 for ticker PML.
# 2026-06-07 15:47:38,451, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/PML/PML_2009
# 2026-06-07 15:47:38,484, data_manager.py, 161, INFO, Processing year 2010 for ticker PML.
# 2026-06-07 15:47:38,493, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/PML/PML_2010
# 2026-06-07 15:47:38,529, data_manager.py, 161, INFO, Processing year 2011 for ticker PML.
# 2026-06-07 15:47:38,541, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/PML/PML_2011
# 2026-06-07 15:47:38,585, data_manager.py, 161, INFO, Processing year 2012 for ticker PML.
# 2026-06-07 15:47:38,595, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/PML/PML_2012
# 2026-06-07 15:47:38,641, data_manager.py, 161, INFO, Processing year 2013 for ticker PML.
# 2026-06-07 15:47:38,650, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/PML/PML_2013
# 2026-06-07 15:47:38,698, data_manager.py, 161, INFO, Processing year 2014 for ticker PML.
# 2026-06-07 15:47:38,709, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/PML/PML_2014
# 2026-06-07 15:47:38,752, data_manager.py, 161, INFO, Processing year 2015 for ticker PML.
# 2026-06-07 15:47:38,762, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/PML/PML_2015
# 2026-06-07 15:47:38,802, data_manager.py, 161, INFO, Processing year 2016 for ticker PML.
# 2026-06-07 15:47:38,812, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/PML/PML_2016
# 2026-06-07 15:47:38,854, data_manager.py, 161, INFO, Processing year 2017 for ticker PML.
# 2026-06-07 15:47:38,862, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/PML/PML_2017
# 2026-06-07 15:47:38,899, data_manager.py, 161, INFO, Processing year 2018 for ticker PML.
# 2026-06-07 15:47:38,909, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/PML/PML_2018
# 2026-06-07 15:47:38,949, data_manager.py, 161, INFO, Processing year 2019 for ticker PML.
# 2026-06-07 15:47:38,957, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/PML/PML_2019
# 2026-06-07 15:47:38,996, data_manager.py, 161, INFO, Processing year 2020 for ticker PML.
# 2026-06-07 15:47:39,004, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/PML/PML_2020
# 2026-06-07 15:47:39,042, data_manager.py, 137, INFO, Processing file ../../05_src/data/prices_csv/stocks/SGU.csv
# 2026-06-07 15:47:39,043, data_manager.py, 186, INFO, Reading file: ../../05_src/data/prices_csv/stocks/SGU.csv
# 2026-06-07 15:47:39,067, data_manager.py, 155, INFO, Saving data by year
# 2026-06-07 15:47:39,069, data_manager.py, 157, INFO, Processing ticker: SGU
# 2026-06-07 15:47:39,076, data_manager.py, 161, INFO, Processing year 1995 for ticker SGU.
# 2026-06-07 15:47:39,090, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/SGU/SGU_1995
# 2026-06-07 15:47:39,143, data_manager.py, 161, INFO, Processing year 1996 for ticker SGU.
# 2026-06-07 15:47:39,153, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/SGU/SGU_1996
# 2026-06-07 15:47:39,210, data_manager.py, 161, INFO, Processing year 1997 for ticker SGU.
# 2026-06-07 15:47:39,219, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/SGU/SGU_1997
# 2026-06-07 15:47:39,266, data_manager.py, 161, INFO, Processing year 1998 for ticker SGU.
# 2026-06-07 15:47:39,277, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/SGU/SGU_1998
# 2026-06-07 15:47:39,317, data_manager.py, 161, INFO, Processing year 1999 for ticker SGU.
# 2026-06-07 15:47:39,328, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/SGU/SGU_1999
# 2026-06-07 15:47:39,373, data_manager.py, 161, INFO, Processing year 2000 for ticker SGU.
# 2026-06-07 15:47:39,385, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/SGU/SGU_2000
# 2026-06-07 15:47:39,423, data_manager.py, 161, INFO, Processing year 2001 for ticker SGU.
# 2026-06-07 15:47:39,437, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/SGU/SGU_2001
# 2026-06-07 15:47:39,478, data_manager.py, 161, INFO, Processing year 2002 for ticker SGU.
# 2026-06-07 15:47:39,486, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/SGU/SGU_2002
# 2026-06-07 15:47:39,521, data_manager.py, 161, INFO, Processing year 2003 for ticker SGU.
# 2026-06-07 15:47:39,536, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/SGU/SGU_2003
# 2026-06-07 15:47:39,578, data_manager.py, 161, INFO, Processing year 2004 for ticker SGU.
# 2026-06-07 15:47:39,587, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/SGU/SGU_2004
# 2026-06-07 15:47:39,626, data_manager.py, 161, INFO, Processing year 2005 for ticker SGU.
# 2026-06-07 15:47:39,635, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/SGU/SGU_2005
# 2026-06-07 15:47:39,670, data_manager.py, 161, INFO, Processing year 2006 for ticker SGU.
# 2026-06-07 15:47:39,681, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/SGU/SGU_2006
# 2026-06-07 15:47:39,717, data_manager.py, 161, INFO, Processing year 2007 for ticker SGU.
# 2026-06-07 15:47:39,729, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/SGU/SGU_2007
# 2026-06-07 15:47:39,761, data_manager.py, 161, INFO, Processing year 2008 for ticker SGU.
# 2026-06-07 15:47:39,772, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/SGU/SGU_2008
# 2026-06-07 15:47:39,815, data_manager.py, 161, INFO, Processing year 2009 for ticker SGU.
# 2026-06-07 15:47:39,827, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/SGU/SGU_2009
# 2026-06-07 15:47:39,866, data_manager.py, 161, INFO, Processing year 2010 for ticker SGU.
# 2026-06-07 15:47:39,878, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/SGU/SGU_2010
# 2026-06-07 15:47:39,911, data_manager.py, 161, INFO, Processing year 2011 for ticker SGU.
# 2026-06-07 15:47:39,920, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/SGU/SGU_2011
# 2026-06-07 15:47:39,960, data_manager.py, 161, INFO, Processing year 2012 for ticker SGU.
# 2026-06-07 15:47:39,969, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/SGU/SGU_2012
# 2026-06-07 15:47:40,037, data_manager.py, 161, INFO, Processing year 2013 for ticker SGU.
# 2026-06-07 15:47:40,051, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/SGU/SGU_2013
# 2026-06-07 15:47:40,096, data_manager.py, 161, INFO, Processing year 2014 for ticker SGU.
# 2026-06-07 15:47:40,107, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/SGU/SGU_2014
# 2026-06-07 15:47:40,147, data_manager.py, 161, INFO, Processing year 2015 for ticker SGU.
# 2026-06-07 15:47:40,154, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/SGU/SGU_2015
# 2026-06-07 15:47:40,192, data_manager.py, 161, INFO, Processing year 2016 for ticker SGU.
# 2026-06-07 15:47:40,199, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/SGU/SGU_2016
# 2026-06-07 15:47:40,237, data_manager.py, 161, INFO, Processing year 2017 for ticker SGU.
# 2026-06-07 15:47:40,246, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/SGU/SGU_2017
# 2026-06-07 15:47:40,282, data_manager.py, 161, INFO, Processing year 2018 for ticker SGU.
# 2026-06-07 15:47:40,292, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/SGU/SGU_2018
# 2026-06-07 15:47:40,327, data_manager.py, 161, INFO, Processing year 2019 for ticker SGU.
# 2026-06-07 15:47:40,336, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/SGU/SGU_2019
# 2026-06-07 15:47:40,398, data_manager.py, 161, INFO, Processing year 2020 for ticker SGU.
# 2026-06-07 15:47:40,410, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/SGU/SGU_2020
# 2026-06-07 15:47:40,463, data_manager.py, 137, INFO, Processing file ../../05_src/data/prices_csv/stocks/CENTA.csv
# 2026-06-07 15:47:40,464, data_manager.py, 186, INFO, Reading file: ../../05_src/data/prices_csv/stocks/CENTA.csv
# 2026-06-07 15:47:40,485, data_manager.py, 155, INFO, Saving data by year
# 2026-06-07 15:47:40,486, data_manager.py, 157, INFO, Processing ticker: CENTA
# 2026-06-07 15:47:40,493, data_manager.py, 161, INFO, Processing year 2007 for ticker CENTA.
# 2026-06-07 15:47:40,504, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/CENTA/CENTA_2007
# 2026-06-07 15:47:40,545, data_manager.py, 161, INFO, Processing year 2008 for ticker CENTA.
# 2026-06-07 15:47:40,554, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/CENTA/CENTA_2008
# 2026-06-07 15:47:40,596, data_manager.py, 161, INFO, Processing year 2009 for ticker CENTA.
# 2026-06-07 15:47:40,606, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/CENTA/CENTA_2009
# 2026-06-07 15:47:40,659, data_manager.py, 161, INFO, Processing year 2010 for ticker CENTA.
# 2026-06-07 15:47:40,668, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/CENTA/CENTA_2010
# 2026-06-07 15:47:40,714, data_manager.py, 161, INFO, Processing year 2011 for ticker CENTA.
# 2026-06-07 15:47:40,721, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/CENTA/CENTA_2011
# 2026-06-07 15:47:40,757, data_manager.py, 161, INFO, Processing year 2012 for ticker CENTA.
# 2026-06-07 15:47:40,766, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/CENTA/CENTA_2012
# 2026-06-07 15:47:40,803, data_manager.py, 161, INFO, Processing year 2013 for ticker CENTA.
# 2026-06-07 15:47:40,815, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/CENTA/CENTA_2013
# 2026-06-07 15:47:40,857, data_manager.py, 161, INFO, Processing year 2014 for ticker CENTA.
# 2026-06-07 15:47:40,867, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/CENTA/CENTA_2014
# 2026-06-07 15:47:40,910, data_manager.py, 161, INFO, Processing year 2015 for ticker CENTA.
# 2026-06-07 15:47:40,920, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/CENTA/CENTA_2015
# 2026-06-07 15:47:40,969, data_manager.py, 161, INFO, Processing year 2016 for ticker CENTA.
# 2026-06-07 15:47:40,980, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/CENTA/CENTA_2016
# 2026-06-07 15:47:41,016, data_manager.py, 161, INFO, Processing year 2017 for ticker CENTA.
# 2026-06-07 15:47:41,027, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/CENTA/CENTA_2017
# 2026-06-07 15:47:41,060, data_manager.py, 161, INFO, Processing year 2018 for ticker CENTA.
# 2026-06-07 15:47:41,070, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/CENTA/CENTA_2018
# 2026-06-07 15:47:41,111, data_manager.py, 161, INFO, Processing year 2019 for ticker CENTA.
# 2026-06-07 15:47:41,119, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/CENTA/CENTA_2019
# 2026-06-07 15:47:41,171, data_manager.py, 161, INFO, Processing year 2020 for ticker CENTA.
# 2026-06-07 15:47:41,184, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/CENTA/CENTA_2020
# 2026-06-07 15:47:41,226, data_manager.py, 137, INFO, Processing file ../../05_src/data/prices_csv/stocks/JOF.csv
# 2026-06-07 15:47:41,228, data_manager.py, 186, INFO, Reading file: ../../05_src/data/prices_csv/stocks/JOF.csv
# 2026-06-07 15:47:41,264, data_manager.py, 155, INFO, Saving data by year
# 2026-06-07 15:47:41,266, data_manager.py, 157, INFO, Processing ticker: JOF
# 2026-06-07 15:47:41,272, data_manager.py, 161, INFO, Processing year 1990 for ticker JOF.
# 2026-06-07 15:47:41,284, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/JOF/JOF_1990
# 2026-06-07 15:47:41,326, data_manager.py, 161, INFO, Processing year 1991 for ticker JOF.
# 2026-06-07 15:47:41,337, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/JOF/JOF_1991
# 2026-06-07 15:47:41,400, data_manager.py, 161, INFO, Processing year 1992 for ticker JOF.
# 2026-06-07 15:47:41,412, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/JOF/JOF_1992
# 2026-06-07 15:47:41,456, data_manager.py, 161, INFO, Processing year 1993 for ticker JOF.
# 2026-06-07 15:47:41,467, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/JOF/JOF_1993
# 2026-06-07 15:47:41,556, data_manager.py, 161, INFO, Processing year 1994 for ticker JOF.
# 2026-06-07 15:47:41,568, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/JOF/JOF_1994
# 2026-06-07 15:47:41,651, data_manager.py, 161, INFO, Processing year 1995 for ticker JOF.
# 2026-06-07 15:47:41,666, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/JOF/JOF_1995
# 2026-06-07 15:47:41,724, data_manager.py, 161, INFO, Processing year 1996 for ticker JOF.
# 2026-06-07 15:47:41,738, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/JOF/JOF_1996
# 2026-06-07 15:47:41,793, data_manager.py, 161, INFO, Processing year 1997 for ticker JOF.
# 2026-06-07 15:47:41,805, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/JOF/JOF_1997
# 2026-06-07 15:47:41,867, data_manager.py, 161, INFO, Processing year 1998 for ticker JOF.
# 2026-06-07 15:47:41,883, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/JOF/JOF_1998
# 2026-06-07 15:47:41,931, data_manager.py, 161, INFO, Processing year 1999 for ticker JOF.
# 2026-06-07 15:47:41,940, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/JOF/JOF_1999
# 2026-06-07 15:47:41,976, data_manager.py, 161, INFO, Processing year 2000 for ticker JOF.
# 2026-06-07 15:47:41,986, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/JOF/JOF_2000
# 2026-06-07 15:47:42,029, data_manager.py, 161, INFO, Processing year 2001 for ticker JOF.
# 2026-06-07 15:47:42,040, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/JOF/JOF_2001
# 2026-06-07 15:47:42,085, data_manager.py, 161, INFO, Processing year 2002 for ticker JOF.
# 2026-06-07 15:47:42,098, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/JOF/JOF_2002
# 2026-06-07 15:47:42,136, data_manager.py, 161, INFO, Processing year 2003 for ticker JOF.
# 2026-06-07 15:47:42,146, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/JOF/JOF_2003
# 2026-06-07 15:47:42,182, data_manager.py, 161, INFO, Processing year 2004 for ticker JOF.
# 2026-06-07 15:47:42,192, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/JOF/JOF_2004
# 2026-06-07 15:47:42,235, data_manager.py, 161, INFO, Processing year 2005 for ticker JOF.
# 2026-06-07 15:47:42,246, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/JOF/JOF_2005
# 2026-06-07 15:47:42,292, data_manager.py, 161, INFO, Processing year 2006 for ticker JOF.
# 2026-06-07 15:47:42,302, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/JOF/JOF_2006
# 2026-06-07 15:47:42,341, data_manager.py, 161, INFO, Processing year 2007 for ticker JOF.
# 2026-06-07 15:47:42,351, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/JOF/JOF_2007
# 2026-06-07 15:47:42,393, data_manager.py, 161, INFO, Processing year 2008 for ticker JOF.
# 2026-06-07 15:47:42,403, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/JOF/JOF_2008
# 2026-06-07 15:47:42,448, data_manager.py, 161, INFO, Processing year 2009 for ticker JOF.
# 2026-06-07 15:47:42,458, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/JOF/JOF_2009
# 2026-06-07 15:47:42,499, data_manager.py, 161, INFO, Processing year 2010 for ticker JOF.
# 2026-06-07 15:47:42,508, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/JOF/JOF_2010
# 2026-06-07 15:47:42,554, data_manager.py, 161, INFO, Processing year 2011 for ticker JOF.
# 2026-06-07 15:47:42,565, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/JOF/JOF_2011
# 2026-06-07 15:47:42,602, data_manager.py, 161, INFO, Processing year 2012 for ticker JOF.
# 2026-06-07 15:47:42,610, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/JOF/JOF_2012
# 2026-06-07 15:47:42,646, data_manager.py, 161, INFO, Processing year 2013 for ticker JOF.
# 2026-06-07 15:47:42,724, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/JOF/JOF_2013
# 2026-06-07 15:47:42,793, data_manager.py, 161, INFO, Processing year 2014 for ticker JOF.
# 2026-06-07 15:47:42,810, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/JOF/JOF_2014
# 2026-06-07 15:47:42,862, data_manager.py, 161, INFO, Processing year 2015 for ticker JOF.
# 2026-06-07 15:47:42,874, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/JOF/JOF_2015
# 2026-06-07 15:47:42,918, data_manager.py, 161, INFO, Processing year 2016 for ticker JOF.
# 2026-06-07 15:47:42,929, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/JOF/JOF_2016
# 2026-06-07 15:47:42,964, data_manager.py, 161, INFO, Processing year 2017 for ticker JOF.
# 2026-06-07 15:47:42,974, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/JOF/JOF_2017
# 2026-06-07 15:47:43,011, data_manager.py, 161, INFO, Processing year 2018 for ticker JOF.
# 2026-06-07 15:47:43,022, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/JOF/JOF_2018
# 2026-06-07 15:47:43,071, data_manager.py, 161, INFO, Processing year 2019 for ticker JOF.
# 2026-06-07 15:47:43,086, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/JOF/JOF_2019
# 2026-06-07 15:47:43,151, data_manager.py, 161, INFO, Processing year 2020 for ticker JOF.
# 2026-06-07 15:47:43,162, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/JOF/JOF_2020
# 2026-06-07 15:47:43,206, data_manager.py, 137, INFO, Processing file ../../05_src/data/prices_csv/stocks/OSS.csv
# 2026-06-07 15:47:43,207, data_manager.py, 186, INFO, Reading file: ../../05_src/data/prices_csv/stocks/OSS.csv
# 2026-06-07 15:47:43,217, data_manager.py, 155, INFO, Saving data by year
# 2026-06-07 15:47:43,218, data_manager.py, 157, INFO, Processing ticker: OSS
# 2026-06-07 15:47:43,225, data_manager.py, 161, INFO, Processing year 2018 for ticker OSS.
# 2026-06-07 15:47:43,240, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/OSS/OSS_2018
# 2026-06-07 15:47:43,289, data_manager.py, 161, INFO, Processing year 2019 for ticker OSS.
# 2026-06-07 15:47:43,303, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/OSS/OSS_2019
# 2026-06-07 15:47:43,351, data_manager.py, 161, INFO, Processing year 2020 for ticker OSS.
# 2026-06-07 15:47:43,362, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/OSS/OSS_2020
# 2026-06-07 15:47:43,399, data_manager.py, 137, INFO, Processing file ../../05_src/data/prices_csv/stocks/ZBH.csv
# 2026-06-07 15:47:43,401, data_manager.py, 186, INFO, Reading file: ../../05_src/data/prices_csv/stocks/ZBH.csv
# 2026-06-07 15:47:43,422, data_manager.py, 155, INFO, Saving data by year
# 2026-06-07 15:47:43,426, data_manager.py, 157, INFO, Processing ticker: ZBH
# 2026-06-07 15:47:43,433, data_manager.py, 161, INFO, Processing year 2001 for ticker ZBH.
# 2026-06-07 15:47:43,444, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/ZBH/ZBH_2001
# 2026-06-07 15:47:43,497, data_manager.py, 161, INFO, Processing year 2002 for ticker ZBH.
# 2026-06-07 15:47:43,510, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/ZBH/ZBH_2002
# 2026-06-07 15:47:43,569, data_manager.py, 161, INFO, Processing year 2003 for ticker ZBH.
# 2026-06-07 15:47:43,584, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/ZBH/ZBH_2003
# 2026-06-07 15:47:43,633, data_manager.py, 161, INFO, Processing year 2004 for ticker ZBH.
# 2026-06-07 15:47:43,644, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/ZBH/ZBH_2004
# 2026-06-07 15:47:43,680, data_manager.py, 161, INFO, Processing year 2005 for ticker ZBH.
# 2026-06-07 15:47:43,690, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/ZBH/ZBH_2005
# 2026-06-07 15:47:43,729, data_manager.py, 161, INFO, Processing year 2006 for ticker ZBH.
# 2026-06-07 15:47:43,740, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/ZBH/ZBH_2006
# 2026-06-07 15:47:43,797, data_manager.py, 161, INFO, Processing year 2007 for ticker ZBH.
# 2026-06-07 15:47:43,809, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/ZBH/ZBH_2007
# 2026-06-07 15:47:43,861, data_manager.py, 161, INFO, Processing year 2008 for ticker ZBH.
# 2026-06-07 15:47:43,871, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/ZBH/ZBH_2008
# 2026-06-07 15:47:43,920, data_manager.py, 161, INFO, Processing year 2009 for ticker ZBH.
# 2026-06-07 15:47:43,933, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/ZBH/ZBH_2009
# 2026-06-07 15:47:43,971, data_manager.py, 161, INFO, Processing year 2010 for ticker ZBH.
# 2026-06-07 15:47:43,986, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/ZBH/ZBH_2010
# 2026-06-07 15:47:44,041, data_manager.py, 161, INFO, Processing year 2011 for ticker ZBH.
# 2026-06-07 15:47:44,052, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/ZBH/ZBH_2011
# 2026-06-07 15:47:44,100, data_manager.py, 161, INFO, Processing year 2012 for ticker ZBH.
# 2026-06-07 15:47:44,111, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/ZBH/ZBH_2012
# 2026-06-07 15:47:44,156, data_manager.py, 161, INFO, Processing year 2013 for ticker ZBH.
# 2026-06-07 15:47:44,166, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/ZBH/ZBH_2013
# 2026-06-07 15:47:44,210, data_manager.py, 161, INFO, Processing year 2014 for ticker ZBH.
# 2026-06-07 15:47:44,224, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/ZBH/ZBH_2014
# 2026-06-07 15:47:44,274, data_manager.py, 161, INFO, Processing year 2015 for ticker ZBH.
# 2026-06-07 15:47:44,288, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/ZBH/ZBH_2015
# 2026-06-07 15:47:44,335, data_manager.py, 161, INFO, Processing year 2016 for ticker ZBH.
# 2026-06-07 15:47:44,346, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/ZBH/ZBH_2016
# 2026-06-07 15:47:44,394, data_manager.py, 161, INFO, Processing year 2017 for ticker ZBH.
# 2026-06-07 15:47:44,402, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/ZBH/ZBH_2017
# 2026-06-07 15:47:44,461, data_manager.py, 161, INFO, Processing year 2018 for ticker ZBH.
# 2026-06-07 15:47:44,469, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/ZBH/ZBH_2018
# 2026-06-07 15:47:44,519, data_manager.py, 161, INFO, Processing year 2019 for ticker ZBH.
# 2026-06-07 15:47:44,534, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/ZBH/ZBH_2019
# 2026-06-07 15:47:44,590, data_manager.py, 161, INFO, Processing year 2020 for ticker ZBH.
# 2026-06-07 15:47:44,600, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/ZBH/ZBH_2020
# 2026-06-07 15:47:44,648, data_manager.py, 137, INFO, Processing file ../../05_src/data/prices_csv/stocks/SPKEP.csv
# 2026-06-07 15:47:44,649, data_manager.py, 186, INFO, Reading file: ../../05_src/data/prices_csv/stocks/SPKEP.csv
# 2026-06-07 15:47:44,661, data_manager.py, 155, INFO, Saving data by year
# 2026-06-07 15:47:44,663, data_manager.py, 157, INFO, Processing ticker: SPKEP
# 2026-06-07 15:47:44,668, data_manager.py, 161, INFO, Processing year 2017 for ticker SPKEP.
# 2026-06-07 15:47:44,687, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/SPKEP/SPKEP_2017
# 2026-06-07 15:47:44,744, data_manager.py, 161, INFO, Processing year 2018 for ticker SPKEP.
# 2026-06-07 15:47:44,753, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/SPKEP/SPKEP_2018
# 2026-06-07 15:47:44,792, data_manager.py, 161, INFO, Processing year 2019 for ticker SPKEP.
# 2026-06-07 15:47:44,802, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/SPKEP/SPKEP_2019
# 2026-06-07 15:47:44,848, data_manager.py, 161, INFO, Processing year 2020 for ticker SPKEP.
# 2026-06-07 15:47:44,857, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/SPKEP/SPKEP_2020
# 2026-06-07 15:47:44,898, data_manager.py, 137, INFO, Processing file ../../05_src/data/prices_csv/stocks/HPP.csv
# 2026-06-07 15:47:44,900, data_manager.py, 186, INFO, Reading file: ../../05_src/data/prices_csv/stocks/HPP.csv
# 2026-06-07 15:47:44,917, data_manager.py, 155, INFO, Saving data by year
# 2026-06-07 15:47:44,919, data_manager.py, 157, INFO, Processing ticker: HPP
# 2026-06-07 15:47:44,926, data_manager.py, 161, INFO, Processing year 2010 for ticker HPP.
# 2026-06-07 15:47:44,941, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HPP/HPP_2010
# 2026-06-07 15:47:44,999, data_manager.py, 161, INFO, Processing year 2011 for ticker HPP.
# 2026-06-07 15:47:45,008, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HPP/HPP_2011
# 2026-06-07 15:47:45,050, data_manager.py, 161, INFO, Processing year 2012 for ticker HPP.
# 2026-06-07 15:47:45,062, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HPP/HPP_2012
# 2026-06-07 15:47:45,117, data_manager.py, 161, INFO, Processing year 2013 for ticker HPP.
# 2026-06-07 15:47:45,129, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HPP/HPP_2013
# 2026-06-07 15:47:45,170, data_manager.py, 161, INFO, Processing year 2014 for ticker HPP.
# 2026-06-07 15:47:45,181, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HPP/HPP_2014
# 2026-06-07 15:47:45,220, data_manager.py, 161, INFO, Processing year 2015 for ticker HPP.
# 2026-06-07 15:47:45,232, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HPP/HPP_2015
# 2026-06-07 15:47:45,270, data_manager.py, 161, INFO, Processing year 2016 for ticker HPP.
# 2026-06-07 15:47:45,283, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HPP/HPP_2016
# 2026-06-07 15:47:45,320, data_manager.py, 161, INFO, Processing year 2017 for ticker HPP.
# 2026-06-07 15:47:45,332, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HPP/HPP_2017
# 2026-06-07 15:47:45,376, data_manager.py, 161, INFO, Processing year 2018 for ticker HPP.
# 2026-06-07 15:47:45,387, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HPP/HPP_2018
# 2026-06-07 15:47:45,464, data_manager.py, 161, INFO, Processing year 2019 for ticker HPP.
# 2026-06-07 15:47:45,475, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HPP/HPP_2019
# 2026-06-07 15:47:45,522, data_manager.py, 161, INFO, Processing year 2020 for ticker HPP.
# 2026-06-07 15:47:45,533, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HPP/HPP_2020
# 2026-06-07 15:47:45,573, data_manager.py, 137, INFO, Processing file ../../05_src/data/prices_csv/stocks/CWCO.csv
# 2026-06-07 15:47:45,574, data_manager.py, 186, INFO, Reading file: ../../05_src/data/prices_csv/stocks/CWCO.csv
# 2026-06-07 15:47:45,608, data_manager.py, 155, INFO, Saving data by year
# 2026-06-07 15:47:45,610, data_manager.py, 157, INFO, Processing ticker: CWCO
# 2026-06-07 15:47:45,616, data_manager.py, 161, INFO, Processing year 1995 for ticker CWCO.
# 2026-06-07 15:47:45,628, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/CWCO/CWCO_1995
# 2026-06-07 15:47:45,664, data_manager.py, 161, INFO, Processing year 1996 for ticker CWCO.
# 2026-06-07 15:47:45,674, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/CWCO/CWCO_1996
# 2026-06-07 15:47:45,713, data_manager.py, 161, INFO, Processing year 1997 for ticker CWCO.
# 2026-06-07 15:47:45,730, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/CWCO/CWCO_1997
# ...
# 2026-06-07 15:48:04,825, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/BGCP/BGCP_2006
# 2026-06-07 15:48:04,877, data_manager.py, 161, INFO, Processing year 2007 for ticker BGCP.
# 2026-06-07 15:48:04,889, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/BGCP/BGCP_2007
# 2026-06-07 15:48:04,939, data_manager.py, 161, INFO, Processing year 2008 for ticker BGCP.
# 2026-06-07 15:48:04,950, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/BGCP/BGCP_2008
# 2026-06-07 15:48:05,005, data_manager.py, 161, INFO, Processing year 2009 for ticker BGCP.
# 2026-06-07 15:48:05,017, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/BGCP/BGCP_2009
# 2026-06-07 15:48:05,075, data_manager.py, 161, INFO, Processing year 2010 for ticker BGCP.
# 2026-06-07 15:48:05,087, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/BGCP/BGCP_2010
# 2026-06-07 15:48:05,143, data_manager.py, 161, INFO, Processing year 2011 for ticker BGCP.
# 2026-06-07 15:48:05,154, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/BGCP/BGCP_2011
# 2026-06-07 15:48:05,211, data_manager.py, 161, INFO, Processing year 2012 for ticker BGCP.
# 2026-06-07 15:48:05,223, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/BGCP/BGCP_2012
# 2026-06-07 15:48:05,275, data_manager.py, 161, INFO, Processing year 2013 for ticker BGCP.
# 2026-06-07 15:48:05,287, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/BGCP/BGCP_2013
# 2026-06-07 15:48:05,341, data_manager.py, 161, INFO, Processing year 2014 for ticker BGCP.
# 2026-06-07 15:48:05,352, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/BGCP/BGCP_2014
# 2026-06-07 15:48:05,405, data_manager.py, 161, INFO, Processing year 2015 for ticker BGCP.
# 2026-06-07 15:48:05,417, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/BGCP/BGCP_2015
# 2026-06-07 15:48:05,471, data_manager.py, 161, INFO, Processing year 2016 for ticker BGCP.
# 2026-06-07 15:48:05,485, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/BGCP/BGCP_2016
# 2026-06-07 15:48:05,541, data_manager.py, 161, INFO, Processing year 2017 for ticker BGCP.
# 2026-06-07 15:48:05,550, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/BGCP/BGCP_2017
# 2026-06-07 15:48:05,598, data_manager.py, 161, INFO, Processing year 2018 for ticker BGCP.
# 2026-06-07 15:48:05,610, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/BGCP/BGCP_2018
# 2026-06-07 15:48:05,689, data_manager.py, 161, INFO, Processing year 2019 for ticker BGCP.
# 2026-06-07 15:48:05,700, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/BGCP/BGCP_2019
# 2026-06-07 15:48:05,757, data_manager.py, 161, INFO, Processing year 2020 for ticker BGCP.
# 2026-06-07 15:48:05,768, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/BGCP/BGCP_2020
# 2026-06-07 15:48:05,822, data_manager.py, 137, INFO, Processing file ../../05_src/data/prices_csv/stocks/NBR.csv
# 2026-06-07 15:48:05,824, data_manager.py, 186, INFO, Reading file: ../../05_src/data/prices_csv/stocks/NBR.csv
# 2026-06-07 15:48:05,874, data_manager.py, 155, INFO, Saving data by year
# 2026-06-07 15:48:05,877, data_manager.py, 157, INFO, Processing ticker: NBR
# 2026-06-07 15:48:05,886, data_manager.py, 161, INFO, Processing year 1973 for ticker NBR.
# 2026-06-07 15:48:05,899, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/NBR/NBR_1973
# 2026-06-07 15:48:05,949, data_manager.py, 161, INFO, Processing year 1974 for ticker NBR.
# 2026-06-07 15:48:05,961, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/NBR/NBR_1974
# 2026-06-07 15:48:06,008, data_manager.py, 161, INFO, Processing year 1975 for ticker NBR.
# 2026-06-07 15:48:06,019, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/NBR/NBR_1975
# 2026-06-07 15:48:06,077, data_manager.py, 161, INFO, Processing year 1976 for ticker NBR.
# 2026-06-07 15:48:06,089, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/NBR/NBR_1976
# 2026-06-07 15:48:06,134, data_manager.py, 161, INFO, Processing year 1977 for ticker NBR.
# 2026-06-07 15:48:06,143, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/NBR/NBR_1977
# 2026-06-07 15:48:06,181, data_manager.py, 161, INFO, Processing year 1978 for ticker NBR.
# 2026-06-07 15:48:06,191, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/NBR/NBR_1978
# 2026-06-07 15:48:06,232, data_manager.py, 161, INFO, Processing year 1979 for ticker NBR.
# 2026-06-07 15:48:06,242, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/NBR/NBR_1979
# 2026-06-07 15:48:06,283, data_manager.py, 161, INFO, Processing year 1980 for ticker NBR.
# 2026-06-07 15:48:06,293, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/NBR/NBR_1980
# 2026-06-07 15:48:06,331, data_manager.py, 161, INFO, Processing year 1981 for ticker NBR.
# 2026-06-07 15:48:06,342, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/NBR/NBR_1981
# 2026-06-07 15:48:06,378, data_manager.py, 161, INFO, Processing year 1982 for ticker NBR.
# 2026-06-07 15:48:06,387, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/NBR/NBR_1982
# 2026-06-07 15:48:06,427, data_manager.py, 161, INFO, Processing year 1983 for ticker NBR.
# 2026-06-07 15:48:06,438, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/NBR/NBR_1983
# 2026-06-07 15:48:06,485, data_manager.py, 161, INFO, Processing year 1984 for ticker NBR.
# 2026-06-07 15:48:06,497, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/NBR/NBR_1984
# 2026-06-07 15:48:06,542, data_manager.py, 161, INFO, Processing year 1985 for ticker NBR.
# 2026-06-07 15:48:06,551, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/NBR/NBR_1985
# 2026-06-07 15:48:06,592, data_manager.py, 161, INFO, Processing year 1986 for ticker NBR.
# 2026-06-07 15:48:06,601, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/NBR/NBR_1986
# 2026-06-07 15:48:06,668, data_manager.py, 161, INFO, Processing year 1987 for ticker NBR.
# 2026-06-07 15:48:06,684, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/NBR/NBR_1987
# 2026-06-07 15:48:06,793, data_manager.py, 161, INFO, Processing year 1988 for ticker NBR.
# 2026-06-07 15:48:06,819, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/NBR/NBR_1988
# 2026-06-07 15:48:06,862, data_manager.py, 161, INFO, Processing year 1989 for ticker NBR.
# 2026-06-07 15:48:06,869, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/NBR/NBR_1989
# 2026-06-07 15:48:06,901, data_manager.py, 161, INFO, Processing year 1990 for ticker NBR.
# 2026-06-07 15:48:06,911, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/NBR/NBR_1990
# 2026-06-07 15:48:06,948, data_manager.py, 161, INFO, Processing year 1991 for ticker NBR.
# 2026-06-07 15:48:06,959, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/NBR/NBR_1991
# 2026-06-07 15:48:06,999, data_manager.py, 161, INFO, Processing year 1992 for ticker NBR.
# 2026-06-07 15:48:07,013, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/NBR/NBR_1992
# 2026-06-07 15:48:07,058, data_manager.py, 161, INFO, Processing year 1993 for ticker NBR.
# 2026-06-07 15:48:07,069, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/NBR/NBR_1993
# 2026-06-07 15:48:07,110, data_manager.py, 161, INFO, Processing year 1994 for ticker NBR.
# 2026-06-07 15:48:07,119, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/NBR/NBR_1994
# 2026-06-07 15:48:07,157, data_manager.py, 161, INFO, Processing year 1995 for ticker NBR.
# 2026-06-07 15:48:07,168, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/NBR/NBR_1995
# 2026-06-07 15:48:07,205, data_manager.py, 161, INFO, Processing year 1996 for ticker NBR.
# 2026-06-07 15:48:07,214, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/NBR/NBR_1996
# 2026-06-07 15:48:07,253, data_manager.py, 161, INFO, Processing year 1997 for ticker NBR.
# 2026-06-07 15:48:07,262, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/NBR/NBR_1997
# 2026-06-07 15:48:07,306, data_manager.py, 161, INFO, Processing year 1998 for ticker NBR.
# 2026-06-07 15:48:07,317, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/NBR/NBR_1998
# 2026-06-07 15:48:07,370, data_manager.py, 161, INFO, Processing year 1999 for ticker NBR.
# 2026-06-07 15:48:07,384, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/NBR/NBR_1999
# 2026-06-07 15:48:07,432, data_manager.py, 161, INFO, Processing year 2000 for ticker NBR.
# 2026-06-07 15:48:07,445, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/NBR/NBR_2000
# 2026-06-07 15:48:07,513, data_manager.py, 161, INFO, Processing year 2001 for ticker NBR.
# 2026-06-07 15:48:07,526, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/NBR/NBR_2001
# 2026-06-07 15:48:07,570, data_manager.py, 161, INFO, Processing year 2002 for ticker NBR.
# 2026-06-07 15:48:07,583, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/NBR/NBR_2002
# 2026-06-07 15:48:07,626, data_manager.py, 161, INFO, Processing year 2003 for ticker NBR.
# 2026-06-07 15:48:07,637, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/NBR/NBR_2003
# 2026-06-07 15:48:07,683, data_manager.py, 161, INFO, Processing year 2004 for ticker NBR.
# 2026-06-07 15:48:07,694, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/NBR/NBR_2004
# 2026-06-07 15:48:07,742, data_manager.py, 161, INFO, Processing year 2005 for ticker NBR.
# 2026-06-07 15:48:07,752, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/NBR/NBR_2005
# 2026-06-07 15:48:07,803, data_manager.py, 161, INFO, Processing year 2006 for ticker NBR.
# 2026-06-07 15:48:07,814, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/NBR/NBR_2006
# 2026-06-07 15:48:07,866, data_manager.py, 161, INFO, Processing year 2007 for ticker NBR.
# 2026-06-07 15:48:07,881, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/NBR/NBR_2007
# 2026-06-07 15:48:07,935, data_manager.py, 161, INFO, Processing year 2008 for ticker NBR.
# 2026-06-07 15:48:07,946, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/NBR/NBR_2008
# 2026-06-07 15:48:07,990, data_manager.py, 161, INFO, Processing year 2009 for ticker NBR.
# 2026-06-07 15:48:07,999, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/NBR/NBR_2009
# 2026-06-07 15:48:08,038, data_manager.py, 161, INFO, Processing year 2010 for ticker NBR.
# 2026-06-07 15:48:08,047, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/NBR/NBR_2010
# 2026-06-07 15:48:08,083, data_manager.py, 161, INFO, Processing year 2011 for ticker NBR.
# 2026-06-07 15:48:08,092, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/NBR/NBR_2011
# 2026-06-07 15:48:08,140, data_manager.py, 161, INFO, Processing year 2012 for ticker NBR.
# 2026-06-07 15:48:08,151, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/NBR/NBR_2012
# 2026-06-07 15:48:08,205, data_manager.py, 161, INFO, Processing year 2013 for ticker NBR.
# 2026-06-07 15:48:08,216, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/NBR/NBR_2013
# 2026-06-07 15:48:08,266, data_manager.py, 161, INFO, Processing year 2014 for ticker NBR.
# 2026-06-07 15:48:08,278, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/NBR/NBR_2014
# 2026-06-07 15:48:08,344, data_manager.py, 161, INFO, Processing year 2015 for ticker NBR.
# 2026-06-07 15:48:08,354, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/NBR/NBR_2015
# 2026-06-07 15:48:08,406, data_manager.py, 161, INFO, Processing year 2016 for ticker NBR.
# 2026-06-07 15:48:08,419, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/NBR/NBR_2016
# 2026-06-07 15:48:08,475, data_manager.py, 161, INFO, Processing year 2017 for ticker NBR.
# 2026-06-07 15:48:08,485, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/NBR/NBR_2017
# 2026-06-07 15:48:08,523, data_manager.py, 161, INFO, Processing year 2018 for ticker NBR.
# 2026-06-07 15:48:08,533, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/NBR/NBR_2018
# 2026-06-07 15:48:08,569, data_manager.py, 161, INFO, Processing year 2019 for ticker NBR.
# 2026-06-07 15:48:08,582, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/NBR/NBR_2019
# 2026-06-07 15:48:08,618, data_manager.py, 161, INFO, Processing year 2020 for ticker NBR.
# 2026-06-07 15:48:08,628, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/NBR/NBR_2020
# 2026-06-07 15:48:08,671, data_manager.py, 137, INFO, Processing file ../../05_src/data/prices_csv/stocks/IMV.csv
# 2026-06-07 15:48:08,673, data_manager.py, 186, INFO, Reading file: ../../05_src/data/prices_csv/stocks/IMV.csv
# 2026-06-07 15:48:08,699, data_manager.py, 155, INFO, Saving data by year
# 2026-06-07 15:48:08,701, data_manager.py, 157, INFO, Processing ticker: IMV
# 2026-06-07 15:48:08,706, data_manager.py, 161, INFO, Processing year 2009 for ticker IMV.
# 2026-06-07 15:48:08,719, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/IMV/IMV_2009
# 2026-06-07 15:48:08,778, data_manager.py, 161, INFO, Processing year 2010 for ticker IMV.
# 2026-06-07 15:48:08,790, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/IMV/IMV_2010
# 2026-06-07 15:48:08,845, data_manager.py, 161, INFO, Processing year 2011 for ticker IMV.
# 2026-06-07 15:48:08,854, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/IMV/IMV_2011
# 2026-06-07 15:48:08,903, data_manager.py, 161, INFO, Processing year 2012 for ticker IMV.
# 2026-06-07 15:48:08,913, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/IMV/IMV_2012
# 2026-06-07 15:48:08,958, data_manager.py, 161, INFO, Processing year 2013 for ticker IMV.
# 2026-06-07 15:48:08,967, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/IMV/IMV_2013
# 2026-06-07 15:48:09,010, data_manager.py, 161, INFO, Processing year 2014 for ticker IMV.
# 2026-06-07 15:48:09,023, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/IMV/IMV_2014
# 2026-06-07 15:48:09,080, data_manager.py, 161, INFO, Processing year 2015 for ticker IMV.
# 2026-06-07 15:48:09,094, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/IMV/IMV_2015
# 2026-06-07 15:48:09,178, data_manager.py, 161, INFO, Processing year 2016 for ticker IMV.
# 2026-06-07 15:48:09,189, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/IMV/IMV_2016
# 2026-06-07 15:48:09,234, data_manager.py, 161, INFO, Processing year 2017 for ticker IMV.
# 2026-06-07 15:48:09,246, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/IMV/IMV_2017
# 2026-06-07 15:48:09,283, data_manager.py, 161, INFO, Processing year 2018 for ticker IMV.
# 2026-06-07 15:48:09,292, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/IMV/IMV_2018
# 2026-06-07 15:48:09,328, data_manager.py, 161, INFO, Processing year 2019 for ticker IMV.
# 2026-06-07 15:48:09,336, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/IMV/IMV_2019
# 2026-06-07 15:48:09,373, data_manager.py, 161, INFO, Processing year 2020 for ticker IMV.
# 2026-06-07 15:48:09,384, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/IMV/IMV_2020

# %% [markdown]
# Finally, add features to the data set and save to a *feature store*.

# %%
dm.featurize()
# Out:
# 2026-06-07 15:48:16,549, data_manager.py, 200, INFO, Creating features data.
# 2026-06-07 15:48:16,552, data_manager.py, 207, INFO, Loading price data from ../../05_src/data/prices/
# 2026-06-07 15:48:17,160, data_manager.py, 244, INFO, Saving features to ../../05_src/data/features/stock_features
